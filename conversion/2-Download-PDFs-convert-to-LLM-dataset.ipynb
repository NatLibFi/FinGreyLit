# %% [markdown]
# # Download PDFs and convert to LLM dataset
#
# This notebook will download the PDF files and convert them to a data set suitable for fine-tuning and evaluating LLMs. Each record will be converted to two fields, "text" and "metadata", where "text" contains the text extracted from the first few pages of the PDF file and "metadata" is a string that represents the metadata of the document in a very simple textual key/value format. In addition, the "id" and "url" fields (containing the document ID/URL and the PDF URL, respectively) will be retained in the new record.

# %%
import os.path
import glob
import json
import re

import fitz
import requests

MAXPAGES = 5  # how many pages of text to extract (maximum)
MARGIN = 2  # how many more pages to look at, in case we can't find text from the first ones
TEXT_MIN = 500  # how many words to aim for (minimum)
TEXT_MAX = 700  # upper limit on # of words

KV_SKIP_FIELDS = {'id', 'url'}  # fields to not include in key-value metadata

METADATA_FIELD_NAMES = {
    "dc.contributor": "Contributor",
    "dc.contributor.author": "Author",
    "dc.contributor.degreeSupervisor": "Supervisor",
    "dc.contributor.department": "Department",
    "dc.contributor.editor": "Editor",
    "dc.contributor.faculty": "Faculty",
    "dc.contributor.opponent": "Opponent",
    "dc.contributor.organization": "Organization",
    "dc.contributor.orgunit": "Org. unit",
    "dc.contributor.reviewer": "Reviewer",
    "dc.contributor.studysubject": "Study subject",
    "dc.contributor.supervisor": "Supervisor",
    "dc.date.issued": "Issued",
    "dc.format.content": None,  # either "fulltext" or "compositeOnly"
    "dc.format.extent": None,  # number of pages - hard to extract
    "dc.format.pagerange": "Page range",
    "dc.identifier.isbn": "Electronic ISBN",
    "dc.identifier.issn": "ISSN",
    "dc.identifier.urn": "URN",
    "dc.language.iso": "Language",
    "dc.publisher": "Publisher",
    "dc.relation.contractor": "Contractor",
    "dc.relation.doi": "DOI",
    "dc.relation.eissn": "eISSN",
    "dc.relation.isbn": "Printed ISBN",
    "dc.relation.ispartofjournal": "Journal name",
    "dc.relation.ispartofseries": "Series name",
    "dc.relation.issn": "Related ISSN",
    "dc.relation.issue": "Issue",
    "dc.relation.isversionof": None,  # very rare
    "dc.relation.numberinseries": "Number in series",
    "dc.relation.url": None,  # rare + usually just same as "url" field
    "dc.relation.volume": "Volume",
    "dc.series.sortingnumber": None,  # rare; should use dc.relation.numberinseries instead
    "dc.series.year": "Series year",
    "dc.source.identifier": None,  # rare + hard to extract
    "dc.subject.degreeprogram": "Degree program",
    "dc.subject.discipline": "Discipline",
    "dc.title": "Title",
    "dc.title.alternative": "Alternative title",
    "dc.type.coar": "COAR type",
    "dc.type.okm": "OKM type",
    "dc.type.ontasot": "Thesis level",    
}

LANG_MAP = {
    'fin': 'fi',
    'swe': 'sv',
    'eng': 'en'
}

LANG_AWARE_FIELDS = (
    'dc.contributor.department',
    'dc.contributor.faculty',
    'dc.contributor.organization',
    'dc.publisher',
    'dc.subject.degreeprogram',
    'dc.subject.discipline',
    'dc.title.alternative',
    'dc.type.coar',
    'dc.type.okm',
    'dc.type.ontasot',
)

metadata_files = glob.glob("../metadata/*/*.jsonl")

def id_to_fn(identifier):
    """convert a URI identifier to a simpler string we can use as a filename for the PDF"""
    return '../pdfs/' + identifier.replace('https://', '').replace('/','_') + ".pdf"

def download(file_url, identifier):
    """download a PDF file, with the given identifier, from the given URL (unless this was done already)
    and return a path to the PDF file"""
    path = id_to_fn(identifier)
    if os.path.exists(path) and os.path.getsize(path) > 0:
        return path

    response = requests.get(file_url)
    with open(path, "wb") as f:
        f.write(response.content)
        print(f"wrote {file_url} as {path}")
    return path

def extract_text(fn):
    """extract and return the first few pages of text from the given PDF file"""
    with fitz.open(fn) as pdf:
        texts = []
        extracted_pages = 0
        extracted_length = 0
        for idx, page in enumerate(list(pdf)[:MAXPAGES + MARGIN]):
            text = page.get_text(sort=True)
            text_length = len(text.strip().split())        
            if extracted_length + text_length < TEXT_MAX:
                texts.append(text)
                extracted_length += text_length
                extracted_pages += 1
            else:
                print(f"skipping page {idx+1} of {fn}: text would become too long")
            if extracted_pages >= MAXPAGES or extracted_length >= TEXT_MIN:
                break
    return '\n'.join(texts)

def choose_value_by_lang(lang, vals):
    lang_vals = {}
    fallback_val = vals[0].split(' {')[0]
    for val in vals:
        m = re.match(r"(.*) {(\w\w)}", val)
        if m:
            lang_vals[m.group(2)] = m.group(1)
        else:
            fallback_val = val
    if lang in lang_vals:
        return lang_vals[lang]
    return fallback_val

def metadata_to_kvtext(rec):
    langcode = LANG_MAP[rec["dc.language.iso"]]
    lines = []
    for fld in sorted(rec.keys()):
        if fld in KV_SKIP_FIELDS:
            continue
        fldname = METADATA_FIELD_NAMES[fld]
        if not fldname:
            continue
        vals = rec[fld]
        if not isinstance(vals, list):
            vals = [vals]
        if fld in LANG_AWARE_FIELDS:
            vals = [choose_value_by_lang(langcode, vals)]
        for val in sorted(vals):
            lines.append(f"{fldname}: {val}")
    return "\n".join(lines)

for mdfile in sorted(metadata_files):
    out_path = mdfile.replace('metadata', 'llm-dataset')
    print(f"converting {mdfile} to {out_path}")
    with open(mdfile) as infile, open(out_path, "w") as outfile:
        for line in infile:
            rec = json.loads(line)
            pdf_path = download(rec["url"], rec["id"])
            pdf_text = extract_text(pdf_path)
            metadata = metadata_to_kvtext(rec)
            print(metadata)
            outrec = {"id": rec["id"], "url": rec["url"], "text": pdf_text, "metadata": metadata}
            json.dump(outrec, outfile)
            outfile.write("\n")
            break
    print()
# Out:
# converting ../metadata/test/docthes-eng.jsonl to ../llm-dataset/test/docthes-eng.jsonl
# Author: Lähdemäki, Sakari
# Supervisor: Professor (emeritus) Matti Viren, University of Turku
# Supervisor: Professor Janne Tukiainen, University of Turku
# Department: Department of Economics
# Faculty: Turku School of Economics
# Opponent: Professor Mika Maliranta, University of Jyväskylä
# Organization: University of Turku
# Reviewer: Professor (emeritus) Pekka Ilmakunnas, Aalto University School of Business
# Reviewer: Professor Mika Maliranta, University of Jyväskylä
# Issued: 2021-03-05
# ISBN: 978-951-29-8349-0
# URN: URN:ISBN:978-951-29-8349-0
# Language: eng
# Publisher: University of Turku, Turku School of Economics
# Related ISBN: 978-951-29-8348-3
# Series name: Turun yliopiston julkaisuja - Annales Universitatis Turkuensis, Ser E: Oeconomica
# Related ISSN: 2343-3167
# Number in series: 74
# Degree program: Doctoral Programme of Turku School of Economics
# Discipline: Economics
# Title: Essays on economic productivity
# Alternative title: Esseitä taloudellisesta tuottavuudesta
# COAR type: väitöskirja
# OKM type: G5 Doctoral dissertation (article)
# Thesis type: Doctoral dissertation (article-based)
#
# converting ../metadata/test/docthes-fin.jsonl to ../llm-dataset/test/docthes-fin.jsonl
# Author: Kaunisto, Siru
# Supervisor: KTT, dosentti Timo Torkkel, Vaasan yliopisto
# Supervisor: KTT, professori Juha Lindgren, Vaasan yliopisto
# Supervisor: OTT, KTT, professori Vesa Annola, Vaasan yliopisto
# Faculty: Laskentatoimen ja rahoituksen yksikkö
# Opponent: OTT, KTM, professori Reijo Knuutinen, Turun yliopisto
# Organization: Vaasan yliopisto
# Reviewer: OTT, KTM, professori Reijo Knuutinen, Turun yliopisto
# Reviewer: OTT, dosentti Matti Urpilainen, Tampereen yliopisto
# Issued: 2022-08-16
# ISBN: 978-952-395-027-6
# URN: URN:ISBN:978-952-395-027-6
# Language: fin
# Publisher: Vaasan yliopisto
# Related ISBN: 978-952-395-026-9
# Series name: Acta Wasaensia
# Related ISSN: 0355-2667
# Related ISSN: 2323-9123
# Number in series: 488
# Discipline: Talousoikeus
# Title: Veron kiertämisen tunnistaminen : oikeuden väärinkäytön kielto VML 28 §:n tulkinnassa
# COAR type: väitöskirja
# OKM type: G4 Monografiaväitöskirja
# Thesis type: Monografiaväitöskirja
#
# converting ../metadata/test/docthes-swe.jsonl to ../llm-dataset/test/docthes-swe.jsonl
# Author: Svanbäck-Laaksonen, Mikaela
# Faculty: Kasvatustieteiden ja hyvinvointialojen tiedekunta
# Opponent: Professor Håkan Larsson, Norges idrottshögskole, Oslo, Norge
# Organization: Åbo Akademi
# Reviewer: Professor Heidi Harju-Luukkainen, FD, Tammerfors universitet
# Reviewer: Professor Håkan Larsson, FD, Norges idrottshögskola
# Supervisor: Dekan Fritjof Sahlström, Åbo Akademi
# Supervisor: Professor Mia Heikkilä, Åbo Akademi
# Issued: 2022-11-04
# ISBN: 978-952-12-4223-6
# URN: URN:ISBN:978-952-12-4223-6
# Language: swe
# Publisher: Åbo Akademi - Åbo Akademi University
# Related ISBN: 978-952-12-4222-9
# Discipline: Pedagogik
# Title: Lärmiljöns betydelse för barns utövande och lärande av grundläggande motoriska färdigheter i småbarnspedagogik
# COAR type: väitöskirja
# OKM type: G5 Artikelavhandling
# Thesis type: Artikkeliväitöskirja
#
# converting ../metadata/test/mono-eng.jsonl to ../llm-dataset/test/mono-eng.jsonl
# Author: Lahti, Johanna
# Editor: Agzamova, Rukhsora
# Editor: Aminov, Inomjon
# Editor: Hoshimzoda, Homid Hasan
# Editor: Komarova, Anastasiya
# Editor: Mirpochoev, Dalerjon
# Editor: Mukhtorov, Saidqosim
# Organization: Laurea University of Applied Sciences
# Issued: 2021
# Page range: 64-69
# ISBN: 978-99975-79-73-7
# URN: URN:NBN:fi-fe202201146983
# Language: eng
# Publisher: Tajik State University of Commerce
# Related ISBN: 978-99975-79-73-7
# Title: Competence-based education development
# COAR type: artikkeli konferenssijulkaisussa
# OKM type: B3 Non-refereed conference proceedings
#
# converting ../metadata/test/mono-fin.jsonl to ../llm-dataset/test/mono-fin.jsonl
# Author: Asikainen, Eveliina
# Author: Kallio, Ella
# Editor: Kenttälä-Koivumäki,  Tiina
# Organization: Tampereen ammattikorkeakoulu
# Issued: 2020
# Page range: 104-111
# ISBN: 978-952-7266-42-7
# URN: URN:NBN:fi-fe2020061142809
# Language: fin
# Publisher: Tampereen ammattikorkeakoulu
# Related ISBN: 978-952-7266-42-7
# Title: Kestävän jätehuollon koulutusosaamista vahvistamassa Venäjällä ja Kazakstanissa
# Alternative title: Enhancing Competences of Sustainable Waste Management in Russian and Kazakh HEIs
# COAR type: artikkeli konferenssijulkaisussa
# OKM type: D3 Artikkeli ammatillisessa konferenssijulkaisussa
#
# converting ../metadata/test/mono-swe.jsonl to ../llm-dataset/test/mono-swe.jsonl
# Org. unit: THL
# Issued: 2022
# URN: URN:NBN:fi-fe202201132199
# Language: swe
# Publisher: Institutet för hälsa och välfärd THL = Terveyden ja hyvinvoinnin laitos
# Title: Norra Österbotten och ojämlikhet : infograf åt välfärdsområdesfullmäktige
# Alternative title: Pohjois-Pohjanmaa ja eriarvoisuus : infograafi aluevaltuutetulle
# OKM type: E1 Yleistajuinen artikkeli, sanomalehtiartikkeli
#
# converting ../metadata/test/serial-eng.jsonl to ../llm-dataset/test/serial-eng.jsonl
# skipping page 2 of ../pdfs/osuva.uwasa.fi_handle_10024_11652.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11652.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11652.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11652.pdf: text would become too long
# Author: Catalão, João P. S.
# Author: Setayesh Nazar, Mehrdad
# Author: Shafie-khah, Miadreza
# Author: Tabatabaei, Mostafa
# Department: Vebic
# Faculty: School of Technology and Innovations
# Organization: University of Vaasa
# Issued: 2020-10-13
# ISBN: 978-1-7281-6919-4
# URN: URN:NBN:fi-fe2020120299133
# Language: eng
# Publisher: IEEE
# DOI: 10.1109/EEM49802.2020.9221905
# Related ISSN: 2165-4077
# Related ISSN: 2165-4093
# Discipline: Electrical Engineering
# Title: A Dynamic Collusion Analysis Framework Considering Generation and Transmission Systems Maintenance Constraints
# COAR type: artikkeli konferenssijulkaisussa
# OKM type: A4 Peer-reviewed article in conference proceeding
#
# converting ../metadata/test/serial-fin.jsonl to ../llm-dataset/test/serial-fin.jsonl
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_500709.pdf: text would become too long
# Author: Vuorensyrjä, Matti
# Organization: Poliisiammattikorkeakoulu
# Issued: 2021
# ISBN: 978-951-815-386-6
# URN: URN:NBN:fi-fe2021060132542
# Language: fin
# Publisher: Poliisiammattikorkeakoulu
# Series name: Poliisiammattikorkeakoulun raportteja
# Related ISSN: 1797-5743
# Number in series: 138
# Series year: 2021
# Title: Poliisikoulutuksen vaikuttavuusarviointi 2021 : vuosina 2018-2019 valmistuneiden poliisien työllisyys ja arviot koulutuksen työelämävastaavuudesta
# Alternative title: Utvärdering av polisutbildningsens effektivitetet 2021 : Sysselsättningen bland poliser som utexaminerats åren 2018–2019 och bedömningar av utbildningens arbetslivsmotsvarighet
# COAR type: tutkimusraportti
# OKM type: D4 Julkaistu kehittämis- tai tutkimusraportti taikka selvitys
#
# converting ../metadata/test/serial-swe.jsonl to ../llm-dataset/test/serial-swe.jsonl
# Author: Kazaka, Signe
# Author: Kihlbom, Liselotte
# Author: Lempinen, Katja
# Author: Linna, Mari
# Author: Metsävainio, Marita
# Author: Suvila, Jari
# Author: Valtonen, Ida
# Organization: Oulun ammattikorkeakoulu
# Issued: 2020
# Page range: 24-25
# URN: URN:NBN:fi-fe202103187791
# Language: swe
# Publisher: Suomen kieltenopettajien liitto
# Journal name: Tempus
# Related ISSN: 0355-8053
# Issue: 3
# Number in series: 3
# Series year: 2020
# Title: Mod och glädje att prata svenska online
# COAR type: tidningsartikel
# OKM type: D1 Artikel i en facktidskrift
#
# converting ../metadata/test/thes-eng.jsonl to ../llm-dataset/test/thes-eng.jsonl
# Author: Kossila, Johannes
# Department: Department of Management and Entrepreneurship
# Faculty: Turku School of Economics
# Organization: Turun yliopisto
# Study subject: Information Systems Science {en}
# Study subject: Tietojärjestelmätiede {fi}
# Issued: 2019-11-27
# URN: URN:NBN:fi-fe2019121748536
# Language: eng
# Publisher: Turun yliopisto
# Degree program: Information Systems Science
# Title: A Light Enterprise Information Security Architecture Model for Creating and Improving Security Architecture
# Alternative title: Kevyt yritystietoturva-arkkitehtuurimalli tietoturva-arkkitehtuurin luomiseksi ja kehittämiseksi
# COAR type: master thesis
# OKM type: G2 Pro gradu, diplomityö, ylempi amk-opinnäytetyö
# Thesis type: Master's thesis
#
# converting ../metadata/test/thes-fin.jsonl to ../llm-dataset/test/thes-fin.jsonl
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7339.pdf: text would become too long
# Author: Kauppinen, Sakari
# Organization: Taideyliopiston Sibelius-Akatemia, Musiikkikasvatuksen, jazzin ja kansanmusiikin osasto, Musiikkikasvatus
# URN: URN:NBN:fi-fe2021061537410
# Language: fin
# Publisher: Taideyliopiston Sibelius-Akatemia
# Degree program: musiikkikasvatus
# Title: Musiikinopettajan pedagogisten lähestymistapojen vaikutus murrosikäisen oppilaan motivaatioon
# COAR type: opinnäyte (kandidaatti)
# OKM type: G1 Ammattikorkeakoulututkinnon opinnäytetyö, kandidaatintyö
# Thesis type: Kandidaatin tutkielma
#
# converting ../metadata/test/thes-swe.jsonl to ../llm-dataset/test/thes-swe.jsonl
# Author: Holmström, Ellinoora
# Faculty: Fakulteten för naturvetenskaper och teknik
# Organization: Åbo Akademi
# URN: URN:NBN:fi-fe202301102207
# Language: swe
# Publisher: Åbo Akademi
# Degree program: Fysikalisk kemi
# Discipline: Molekylärvetenskap och -teknik
# Title: Monitorering av biofilmbildningen med kvartskristallmikrobalans (QCM) och ytplasmonresonans (SPR)
# COAR type: lärdomsprov (magister)
# OKM type: G2 Pro gradu, diplomityö, ylempi amk-opinnäytetyö
# Thesis type: Diplomarbete
#
# converting ../metadata/train/docthes-eng.jsonl to ../llm-dataset/train/docthes-eng.jsonl
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_13675.pdf: text would become too long
# Author: Li, Fang Fang
# Faculty: School of Marketing and Communication
# Organization: University of Vaasa
# Reviewer: Karjaluoto, Heikki
# Reviewer: Nijssen, Edwin
# Issued: 2022-04-28
# ISBN: 978-952-395-020-7
# URN: URN:ISBN:978-952-395-020-7
# Language: eng
# Publisher: Vaasan yliopisto
# Related ISBN: 978-952-395-019-1
# Series name: Acta Wasaensia
# Related ISSN: 0355-2667
# Related ISSN: 2323-9123
# Number in series: 485
# Discipline: International Business
# Title: The integration of social media and marketing strategy : tactics, strategy, and culture
# Alternative title: Sosiaalisen median ja markkinointistrategian integrointi : taktiikat, strategia ja kulttuuri
# COAR type: väitöskirja
# OKM type: G5 Doctoral dissertation (article)
# Thesis type: Doctoral dissertation (article-based)
#
# converting ../metadata/train/docthes-fin.jsonl to ../llm-dataset/train/docthes-fin.jsonl
# Author: Syväsalmi, Emilia
# Supervisor: Apulaisprofessori Tuomas Räsänen, Itä-Suomen yliopisto
# Supervisor: Professori Taina Syrjämaa, Turun yliopisto
# Department: Historian, kulttuurin ja taiteiden tutkimuksen laitos
# Faculty: Humanistinen tiedekunta
# Opponent: PhD Sari Mäenpää, Forum Marinum
# Organization: Turun yliopisto
# Reviewer: FT Kirsi Keravuori, Suomalaisen kirjallisuuden seura
# Reviewer: PhD Sari Mäenpää, Forum Marinum
# Issued: 2022-10-28
# ISBN: 978-951-29-8996-6
# URN: URN:ISBN:978-951-29-8996-6
# Language: fin
# Publisher: Turun yliopisto
# Related ISBN: 978-951-29-8995-9
# Series name: Turun yliopiston julkaisua - Annales Universitatis Turkuensis, Ser. B: Humaniora
# Related ISSN: 2343-3191
# Number in series: 591
# Degree program: Historian, kulttuurin ja taiteiden tutkimuksen tohtoriohjelma (Juno)
# Discipline: Yleinen historia
# Title: Kapteenien vaimojen kokemus elämästä laivayhteisössä yhdysvaltalaisilla valaanpyyntialuksilla 1840–1870
# Alternative title: Life on ship community experienced by the captains’ wives on board the US whaling ships 1840–1870
# COAR type: väitöskirja
# OKM type: G5 Artikkeliväitöskirja
# Thesis type: Artikkeliväitöskirja
#
# converting ../metadata/train/docthes-swe.jsonl to ../llm-dataset/train/docthes-swe.jsonl
# Author: Harjunen, Catarina
# Faculty: Fakulteten för humaniora, psykologi och teologi
# Opponent: Docent, lektor Maria Bäckman, Stockholms universitet
# Organization: Åbo Akademi
# Supervisor: Biträdande professor Lena Marander-Eklund, Åbo Akademi
# Supervisor: Docent Blanka Henriksson, Åbo Akademi
# Issued: 2020-09-04
# ISBN: 978-951-765-968-0
# URN: URN:ISBN:978-951-765-968-0
# Language: swe
# Publisher: Åbo Akademi
# Related ISBN: 978-951-765-967-3
# Title: Att dansa med de(t) skeva : Erotiska möten mellan människa och naturväsen i finlandssvenska folksägner
# COAR type: väitöskirja
# OKM type: G4 Monografiavhandling
# Thesis type: Doktorsavhandling (monografi)
#
# converting ../metadata/train/mono-eng.jsonl to ../llm-dataset/train/mono-eng.jsonl
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# Author: Koivisto, Taru-Anneli
# Issued: 2021
# Page range: 115-128
# URN: URN:NBN:fi-fe2021072041630
# Language: eng
# Publisher: Routledge
# DOI: 10.4324/9781003108337-10
# Related ISBN: 9781003108337
# Title: Making our way through the deep waters of life: Music practitioners' professional work in neonatal intensive care units
# COAR type: book part
# OKM type: B2 Kirjan tai muun kokoomateoksen osa
#
# converting ../metadata/train/mono-fin.jsonl to ../llm-dataset/train/mono-fin.jsonl
# Editor: Marjut Pietiläinen
# Organization: Tilastokeskus
# Issued: 2013
# ISBN: 978–952–244–457–8
# URN: URN:ISBN:978–952–244–457–8
# Language: fin
# Publisher: Tilastokeskus
# Related ISBN: 978–952–244–412–7
# Title: Työ, talous ja tasa-arvo
# COAR type: kirja
# OKM type: D6 Toimitettu ammatillinen teos
#
# converting ../metadata/train/mono-swe.jsonl to ../llm-dataset/train/mono-swe.jsonl
# skipping page 2 of ../pdfs/www.julkari.fi_handle_10024_142667.pdf: text would become too long
# skipping page 3 of ../pdfs/www.julkari.fi_handle_10024_142667.pdf: text would become too long
# Author: Aho, Jaakko
# Author: Koivurinne, Kimmo
# Organization: Arbetspensionsförsäkrarna TELA rf
# Issued: 2021-06-07
# URN: URN:NBN:fi-fe2021060434212
# Language: swe
# Publisher: Arbetspensionsförsäkrarna TELA rf
# Title: Arbetspensionsanstalternas bokslutssiffror 2020
# COAR type: tutkimusartikkeli
# OKM type: D1 Artikel i en facktidskrift
#
# converting ../metadata/train/serial-eng.jsonl to ../llm-dataset/train/serial-eng.jsonl
# Contributor: Bank of Finland
# Author: Tuuli, Saara
# Editor: Jokivuolle, Esa
# Organization: Bank of Finland
# Org. unit: Research Unit
# Issued: 2019-02-15
# ISBN: 978-952-323-261-7
# ISSN: 1456-6184
# URN: URN:NBN:fi:bof-201902151065
# Language: eng
# Series name: Bank of Finland Research Discussion Papers
# Series year: 2019
# Title: Model-based regulation and firms' access to finance
# COAR type: tutkimusraportti
# OKM type: D4 Published development or research report or study
#
# converting ../metadata/train/serial-fin.jsonl to ../llm-dataset/train/serial-fin.jsonl
# Author: Antila, Heli
# Author: Lähteenmäki, Eija
# Organization: Tampereen ammattikorkeakoulu
# Issued: 2019
# URN: URN:NBN:fi-fe202003026986
# Language: fin
# Publisher: Tampereen ammattikorkeakoulu
# Journal name: TAMK-blogi
# Series year: 2019
# Title: Virtain metsä- ja liiketalouden opiskelijat pohtivat yhteistyömahdollisuuksia
# COAR type: blogiteksti
# OKM type: E1 Yleistajuinen artikkeli, sanomalehtiartikkeli
#
# converting ../metadata/train/serial-swe.jsonl to ../llm-dataset/train/serial-swe.jsonl
# Contributor: Finansinspektionen
# Issued: 2012-02-15
# ISBN: 978-952-5841-09-1
# ISSN: 1798-1646
# URN: URN:NBN:fi:bof-201408071245
# Language: swe
# Series name: Försäkringsmäklare
# Series year: 2012
# Title: Försäkringsmäklare 2011
# COAR type: tutkimusraportti
# OKM type: D4 Publicerad utvecklings- eller forskningsrapport eller -utredning
#
# converting ../metadata/train/thes-eng.jsonl to ../llm-dataset/train/thes-eng.jsonl
# Author: Hautala, Noora
# Faculty: School of Marketing and Communication
# Organization: University of Vaasa
# Issued: 2020-04-21
# URN: URN:NBN:fi-fe2020042119559
# Language: eng
# Publisher: University of Vaasa
# Degree program: Master's Programme in Comparative Cultural Studies
# Discipline: English language
# Title: “All Magic Comes with a Price” : Rumplestiltskin’s Character Arc in Once Upon a Time
# COAR type: master thesis
# OKM type: G2 Pro gradu, diplomityö, ylempi amk-opinnäytetyö
# Thesis type: Master's thesis
#
# converting ../metadata/train/thes-fin.jsonl to ../llm-dataset/train/thes-fin.jsonl
# Author: Härkönen, Teemu
# Organization: Laurea-ammattikorkeakoulu
# URN: URN:NBN:fi:amk-202003274014
# Language: fin
# Publisher: Laurea-ammattikorkeakoulu
# Contractor: Hämeen poliisilaitos
# Degree program: Turvallisuus ja riskienhallinta
# Discipline: Turvallisuusala
# Title: Huumeidenkäyttäjien sitouttaminen hoitoon Päijät-Hämeessä : tapaustutkimus huumeidenkäyttäjiä päihdehoitoon sitouttavista asioista
# Alternative title: Engaging Drug Users to Treatment in Päijät-Häme: A Case Study of Factors That Engage Drug Users to Substance Abuse Treatment
# COAR type: opinnäyte
# OKM type: G1 Ammattikorkeakoulututkinnon opinnäytetyö, kandidaatintyö
# Thesis type: AMK-opinnäytetyö
#
# converting ../metadata/train/thes-swe.jsonl to ../llm-dataset/train/thes-swe.jsonl
# Author: Geust, Miranda
# Faculty: Fakulteten för humaniora, psykologi och teologi
# Organization: Åbo Akademi
# Study subject: Litteraturvetenskap
# URN: URN:NBN:fi-fe2021051830472
# Language: swe
# Publisher: Åbo Akademi
# Title: "En vacker dag har vi vänt så många blad att ingenting av det här har hänt" : Om våldtäktsnarrativ i Monika Fagerholms Vem dödade bambi?
# COAR type: lärdomsprov (magister)
# OKM type: G2 Pro gradu, diplomityö, ylempi amk-opinnäytetyö
# Thesis type: Pro gradu -tutkielma

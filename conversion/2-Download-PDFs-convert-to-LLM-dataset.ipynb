# %% [markdown]
# # Download PDFs and convert to LLM dataset
#
# This notebook will download the PDF files and convert them to a data set suitable for fine-tuning and evaluating LLMs. Each record will be converted to two fields, "text" and "metadata", where "text" contains the text extracted from the first few pages of the PDF file and "metadata" is a string that represents the metadata of the document in a very simple textual key/value format. In addition, the "id" and "url" fields (containing the document ID/URL and the PDF URL, respectively) will be retained in the new record.

# %%
import os.path
import glob
import json
import re

import fitz
import requests

MAXPAGES = 5  # how many pages of text to extract (maximum)
MARGIN = 2  # how many more pages to look at, in case we can't find text from the first ones
TEXT_MIN = 500  # how many words to aim for (minimum)
TEXT_MAX = 700  # upper limit on # of words

KV_SKIP_FIELDS = {'id', 'url', 'rowid', 'repository', 'doctype', 'subset'}  # fields to not include in key-value metadata

METADATA_FIELD_NAMES = {
    "dc.contributor": "Contributor",
    "dc.contributor.author": "Author",
    "dc.contributor.degreeSupervisor": "Supervisor",
    "dc.contributor.department": "Department",
    "dc.contributor.editor": "Editor",
    "dc.contributor.faculty": "Faculty",
    "dc.contributor.opponent": "Opponent",
    "dc.contributor.organization": "Organization",
    "dc.contributor.orgunit": "Org. unit",
    "dc.contributor.reviewer": "Reviewer",
    "dc.contributor.studysubject": "Study subject",
    "dc.contributor.supervisor": "Supervisor",
    "dc.date.issued": "Issued",
    "dc.format.extent": None,  # number of pages - hard to extract
    "dc.format.pagerange": "Page range",
    "dc.identifier.isbn": "ISBN (online)",
    "dc.identifier.urn": "URN",
    "dc.language.iso": "Language",
    "dc.publisher": "Publisher",
    "dc.relation.contractor": "Contractor",
    "dc.relation.doi": "DOI",
    "dc.relation.eissn": "ISSN (online)",
    "dc.relation.isbn": "ISBN (printed)",
    "dc.relation.ispartofjournal": "Journal name",
    "dc.relation.ispartofseries": "Series name",
    "dc.relation.issue": "Issue",
    "dc.relation.numberinseries": "Number in series",
    "dc.relation.pissn": "ISSN (printed)",
    "dc.relation.volume": "Volume",
    "dc.series.year": "Series year",
    "dc.source.identifier": None,  # rare + hard to extract
    "dc.subject.degreeprogram": "Degree program",
    "dc.subject.discipline": "Discipline",
    "dc.title": "Title",
    "dc.title.alternative": "Alternative title",
    "dc.type.coar": "COAR type",
    "dc.type.okm": "OKM type",
    "dc.type.ontasot": "Thesis level",    
}

LANG_MAP = {
    'fin': 'fi',
    'swe': 'sv',
    'eng': 'en'
}

LANG_AWARE_FIELDS = (
    'dc.contributor.department',
    'dc.contributor.faculty',
    'dc.contributor.organization',
    'dc.subject.degreeprogram',
    'dc.subject.discipline',
    'dc.title.alternative',
)

metadata_files = glob.glob("../metadata/*.jsonl")

def id_to_fn(identifier):
    """convert a URI identifier to a simpler string we can use as a filename for the PDF"""
    return '../pdfs/' + identifier.replace('https://', '').replace('/','_') + ".pdf"

def download(file_url, identifier):
    """download a PDF file, with the given identifier, from the given URL (unless this was done already)
    and return a path to the PDF file"""
    path = id_to_fn(identifier)
    if os.path.exists(path) and os.path.getsize(path) > 0:
        return path

    response = requests.get(file_url)
    with open(path, "wb") as f:
        f.write(response.content)
        print(f"wrote {file_url} as {path}")
    return path

def extract_text(fn):
    """extract and return the first few pages of text from the given PDF file"""
    with fitz.open(fn) as pdf:
        texts = []
        extracted_pages = 0
        extracted_length = 0
        for idx, page in enumerate(list(pdf)[:MAXPAGES + MARGIN]):
            text = page.get_text(sort=True)
            text_length = len(text.strip().split())        
            if extracted_length + text_length < TEXT_MAX:
                texts.append(text)
                extracted_length += text_length
                extracted_pages += 1
            else:
                print(f"skipping page {idx+1} of {fn}: text would become too long")
            if extracted_pages >= MAXPAGES or extracted_length >= TEXT_MIN:
                break
    return '\n'.join(texts)

def choose_value_by_lang(lang, vals):
    lang_vals = {}
    fallback_val = vals[0].split(' {')[0]
    for val in vals:
        m = re.match(r"(.*) {(\w\w)}", val)
        if m:
            lang_vals[m.group(2)] = m.group(1)
        else:
            fallback_val = val
    if lang in lang_vals:
        return lang_vals[lang]
    return fallback_val

def metadata_to_kvtext(rec):
    langcode = LANG_MAP[rec["dc.language.iso"]]
    lines = []
    for fld in sorted(rec.keys()):
        if fld in KV_SKIP_FIELDS:
            continue
        fldname = METADATA_FIELD_NAMES[fld]
        if not fldname:
            continue
        vals = rec[fld]
        if not isinstance(vals, list):
            vals = [vals]
        if fld in LANG_AWARE_FIELDS:
            vals = [choose_value_by_lang(langcode, vals)]
        for val in sorted(vals):
            lines.append(f"{fldname}: {val}")
    return "\n".join(lines)

for mdfile in sorted(metadata_files):
    out_path = mdfile.replace('metadata', 'llm-dataset')
    print(f"converting {mdfile} to {out_path}")
    with open(mdfile) as infile, open(out_path, "w") as outfile:
        for line in infile:
            rec = json.loads(line)
            pdf_path = download(rec["url"], rec["id"])
            pdf_text = extract_text(pdf_path)
            metadata = metadata_to_kvtext(rec)
            #print(metadata)
            outrec = {"id": rec["id"], "url": rec["url"], "text": pdf_text, "metadata": metadata}
            json.dump(outrec, outfile)
            outfile.write("\n")
            #break
    print()
# Out:
# converting ../metadata/docthes-eng-test.jsonl to ../llm-dataset/docthes-eng-test.jsonl
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_12300.pdf: text would become too long
#
# converting ../metadata/docthes-eng-train.jsonl to ../llm-dataset/docthes-eng-train.jsonl
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_13675.pdf: text would become too long
# skipping page 5 of ../pdfs/trepo.tuni.fi_handle_10024_130697.pdf: text would become too long
# skipping page 4 of ../pdfs/lutpub.lut.fi_handle_10024_164949.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_13152.pdf: text would become too long
#
# converting ../metadata/docthes-fin-test.jsonl to ../llm-dataset/docthes-fin-test.jsonl
#
# converting ../metadata/docthes-fin-train.jsonl to ../llm-dataset/docthes-fin-train.jsonl
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_13779.pdf: text would become too long
# skipping page 5 of ../pdfs/www.utupub.fi_handle_10024_150674.pdf: text would become too long
# skipping page 6 of ../pdfs/www.utupub.fi_handle_10024_150674.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_13521.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_13205.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_13119.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_13614.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_12481.pdf: text would become too long
#
# converting ../metadata/docthes-swe-test.jsonl to ../llm-dataset/docthes-swe-test.jsonl
# skipping page 5 of ../pdfs/www.doria.fi_handle_10024_186036.pdf: text would become too long
#
# converting ../metadata/docthes-swe-train.jsonl to ../llm-dataset/docthes-swe-train.jsonl
#
# converting ../metadata/mono-eng-test.jsonl to ../llm-dataset/mono-eng-test.jsonl
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11734.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11734.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11734.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_11734.pdf: text would become too long
# skipping page 7 of ../pdfs/osuva.uwasa.fi_handle_10024_11734.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7481.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7481.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7481.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7481.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7481.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7481.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_6005.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_6005.pdf: text would become too long
# skipping page 2 of ../pdfs/www.julkari.fi_handle_10024_143524.pdf: text would become too long
# skipping page 3 of ../pdfs/www.julkari.fi_handle_10024_143524.pdf: text would become too long
# skipping page 2 of ../pdfs/osuva.uwasa.fi_handle_10024_11397.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11397.pdf: text would become too long
# skipping page 1 of ../pdfs/taju.uniarts.fi_handle_10024_7713.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7713.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7713.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7713.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_6026.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_6026.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_6026.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_6026.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_6026.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_6026.pdf: text would become too long
#
# converting ../metadata/mono-eng-train.jsonl to ../llm-dataset/mono-eng-train.jsonl
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7352.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_344264.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_344264.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_344264.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_344264.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_344264.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_6033.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_6033.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_6033.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_6033.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_6033.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_354200.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_354200.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_354200.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_354200.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_354200.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_6003.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_6003.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_6003.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_6003.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_6003.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_6003.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7304.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7304.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7304.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7304.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_10361.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_10361.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_10361.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_10361.pdf: text would become too long
# skipping page 7 of ../pdfs/osuva.uwasa.fi_handle_10024_10361.pdf: text would become too long
# skipping page 2 of ../pdfs/osuva.uwasa.fi_handle_10024_11576.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11576.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11576.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11576.pdf: text would become too long
# skipping page 7 of ../pdfs/osuva.uwasa.fi_handle_10024_11576.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_344275.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7750.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7750.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7750.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7750.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7750.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7750.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7723.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7723.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7723.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7723.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7723.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7723.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/345977/HUP_Stocchetti.pdf as ../pdfs/www.theseus.fi_handle_10024_345977.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/745029/Public_service_media_Gronvall.pdf as ../pdfs/www.theseus.fi_handle_10024_745029.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/745027/Commercial_influence_Gronvall.pdf as ../pdfs/www.theseus.fi_handle_10024_745027.pdf
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_180731.pdf: text would become too long
#
# converting ../metadata/mono-fin-test.jsonl to ../llm-dataset/mono-fin-test.jsonl
# skipping page 4 of ../pdfs/www.julkari.fi_handle_10024_139695.pdf: text would become too long
# skipping page 5 of ../pdfs/www.julkari.fi_handle_10024_139695.pdf: text would become too long
# skipping page 6 of ../pdfs/www.julkari.fi_handle_10024_139695.pdf: text would become too long
# skipping page 7 of ../pdfs/www.julkari.fi_handle_10024_139695.pdf: text would become too long
#
# converting ../metadata/mono-fin-train.jsonl to ../llm-dataset/mono-fin-train.jsonl
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7269.pdf: text would become too long
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_313005.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_333964.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_6009.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_6009.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_6009.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_6009.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_6009.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_6009.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7109.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7109.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7109.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7109.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_755715.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_755715.pdf: text would become too long
# skipping page 2 of ../pdfs/www.julkari.fi_handle_10024_142661.pdf: text would become too long
# skipping page 3 of ../pdfs/www.julkari.fi_handle_10024_142661.pdf: text would become too long
# skipping page 4 of ../pdfs/www.julkari.fi_handle_10024_140709.pdf: text would become too long
# skipping page 5 of ../pdfs/www.julkari.fi_handle_10024_140709.pdf: text would become too long
# skipping page 6 of ../pdfs/www.julkari.fi_handle_10024_140709.pdf: text would become too long
# skipping page 7 of ../pdfs/www.julkari.fi_handle_10024_140709.pdf: text would become too long
# skipping page 3 of ../pdfs/www.doria.fi_handle_10024_181089.pdf: text would become too long
# skipping page 4 of ../pdfs/www.doria.fi_handle_10024_181089.pdf: text would become too long
# skipping page 5 of ../pdfs/www.doria.fi_handle_10024_181089.pdf: text would become too long
# skipping page 6 of ../pdfs/www.doria.fi_handle_10024_181089.pdf: text would become too long
# skipping page 7 of ../pdfs/www.doria.fi_handle_10024_181089.pdf: text would become too long
#
# converting ../metadata/mono-swe-test.jsonl to ../llm-dataset/mono-swe-test.jsonl
#
# converting ../metadata/mono-swe-train.jsonl to ../llm-dataset/mono-swe-train.jsonl
# skipping page 2 of ../pdfs/www.julkari.fi_handle_10024_142667.pdf: text would become too long
# skipping page 3 of ../pdfs/www.julkari.fi_handle_10024_142667.pdf: text would become too long
# skipping page 3 of ../pdfs/www.julkari.fi_handle_10024_140653.pdf: text would become too long
# skipping page 4 of ../pdfs/www.julkari.fi_handle_10024_140653.pdf: text would become too long
# skipping page 5 of ../pdfs/www.julkari.fi_handle_10024_140653.pdf: text would become too long
# skipping page 6 of ../pdfs/www.julkari.fi_handle_10024_140653.pdf: text would become too long
# skipping page 4 of ../pdfs/www.doria.fi_handle_10024_185228.pdf: text would become too long
# skipping page 5 of ../pdfs/www.doria.fi_handle_10024_185228.pdf: text would become too long
# skipping page 6 of ../pdfs/www.doria.fi_handle_10024_185228.pdf: text would become too long
# skipping page 7 of ../pdfs/www.doria.fi_handle_10024_185228.pdf: text would become too long
#
# converting ../metadata/serial-eng-test.jsonl to ../llm-dataset/serial-eng-test.jsonl
# skipping page 2 of ../pdfs/osuva.uwasa.fi_handle_10024_11652.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11652.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11652.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11652.pdf: text would become too long
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_184309.pdf: text would become too long
# skipping page 3 of ../pdfs/publications.bof.fi_handle_10024_47321.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_47321.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_47321.pdf: text would become too long
# skipping page 3 of ../pdfs/publications.bof.fi_handle_10024_47827.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_47827.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_47827.pdf: text would become too long
# skipping page 6 of ../pdfs/publications.bof.fi_handle_10024_47827.pdf: text would become too long
# skipping page 7 of ../pdfs/publications.bof.fi_handle_10024_47827.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_504441.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_504441.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/343420/EAPRIL_Stahl_Tore.pdf as ../pdfs/www.theseus.fi_handle_10024_343420.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/333403/EAhil2019_Sarah.pdf as ../pdfs/www.theseus.fi_handle_10024_333403.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/355895/Loukola_et_al_2020_role_temperature_nest_predator_information_use_europe_geographical_variation_egg_covering_tits.pdf as ../pdfs/www.theseus.fi_handle_10024_355895.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_355895.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_355895.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_355895.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_355895.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_355895.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_355895.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/780577/Trustworthy_AI_Covid-19.pdf as ../pdfs/www.theseus.fi_handle_10024_780577.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_780577.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_780577.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_780577.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_780577.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_780577.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_780577.pdf: text would become too long
#
# converting ../metadata/serial-eng-train.jsonl to ../llm-dataset/serial-eng-train.jsonl
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7404.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7404.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7404.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7404.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7404.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7404.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7356.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7356.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7356.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7356.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7356.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7356.pdf: text would become too long
# skipping page 3 of ../pdfs/publications.bof.fi_handle_10024_47256.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_47256.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_47256.pdf: text would become too long
# skipping page 6 of ../pdfs/publications.bof.fi_handle_10024_47256.pdf: text would become too long
# skipping page 7 of ../pdfs/publications.bof.fi_handle_10024_47256.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11181.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11181.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11181.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_11181.pdf: text would become too long
# skipping page 7 of ../pdfs/osuva.uwasa.fi_handle_10024_11181.pdf: text would become too long
# skipping page 2 of ../pdfs/osuva.uwasa.fi_handle_10024_11457.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11457.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11457.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11457.pdf: text would become too long
# skipping page 2 of ../pdfs/osuva.uwasa.fi_handle_10024_11454.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11454.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11454.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11454.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_11454.pdf: text would become too long
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_184325.pdf: text would become too long
# skipping page 2 of ../pdfs/osuva.uwasa.fi_handle_10024_11591.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11591.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11591.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11591.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_11591.pdf: text would become too long
# skipping page 2 of ../pdfs/osuva.uwasa.fi_handle_10024_11850.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11850.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11850.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11850.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_11850.pdf: text would become too long
# skipping page 7 of ../pdfs/osuva.uwasa.fi_handle_10024_11850.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7591.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7591.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7591.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7591.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7591.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7591.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7502.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7502.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7502.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7502.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7502.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7502.pdf: text would become too long
# skipping page 3 of ../pdfs/publications.bof.fi_handle_10024_45164.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_45164.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_45164.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_7258.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7258.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_7258.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_7258.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_7258.pdf: text would become too long
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_509106.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_509106.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_509106.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_47870.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_47870.pdf: text would become too long
# skipping page 6 of ../pdfs/publications.bof.fi_handle_10024_47870.pdf: text would become too long
# skipping page 7 of ../pdfs/publications.bof.fi_handle_10024_47870.pdf: text would become too long
# skipping page 2 of ../pdfs/osuva.uwasa.fi_handle_10024_11287.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11287.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11287.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11287.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_11287.pdf: text would become too long
# skipping page 7 of ../pdfs/osuva.uwasa.fi_handle_10024_11287.pdf: text would become too long
# skipping page 3 of ../pdfs/publications.bof.fi_handle_10024_47378.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_47378.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_47378.pdf: text would become too long
# skipping page 7 of ../pdfs/publications.bof.fi_handle_10024_47378.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_6017.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_6017.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_6017.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_6017.pdf: text would become too long
# skipping page 6 of ../pdfs/taju.uniarts.fi_handle_10024_6017.pdf: text would become too long
# skipping page 7 of ../pdfs/taju.uniarts.fi_handle_10024_6017.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_47680.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_47680.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_745004.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_745004.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_745004.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_745004.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_345047.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_345047.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_345047.pdf: text would become too long
# skipping page 2 of ../pdfs/publications.bof.fi_handle_10024_43566.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/355030/Tjornlov_Et_Al_2020_FEE.pdf as ../pdfs/www.theseus.fi_handle_10024_355030.pdf
# skipping page 2 of ../pdfs/www.julkari.fi_handle_10024_140800.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/343922/Taito_2020_Traskman.pdf as ../pdfs/www.theseus.fi_handle_10024_343922.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/333176/Soderbacka_2019_Vaasa_insider_Energy_storage.pdf as ../pdfs/www.theseus.fi_handle_10024_333176.pdf
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_333176.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_333176.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/780539/Sustainability_Espinosa-Leal.pdf as ../pdfs/www.theseus.fi_handle_10024_780539.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_780539.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_780539.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_780539.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_780539.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/495440/Nursing_competence_Lejonqvist.pdf as ../pdfs/www.theseus.fi_handle_10024_495440.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_495440.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_495440.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_495440.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_495440.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_495440.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/780765/Prediction_Espinosa-Leal.pdf as ../pdfs/www.theseus.fi_handle_10024_780765.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_780765.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_780765.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_780765.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_780765.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/804973/Procedia_Eriksson_and_Stenius.pdf as ../pdfs/www.theseus.fi_handle_10024_804973.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_804973.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_804973.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_804973.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_804973.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_804973.pdf: text would become too long
#
# converting ../metadata/serial-fin-test.jsonl to ../llm-dataset/serial-fin-test.jsonl
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_500709.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_45083.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_45083.pdf: text would become too long
# skipping page 6 of ../pdfs/publications.bof.fi_handle_10024_45083.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11161.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11161.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11161.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_11161.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_743856.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_344430.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_344430.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/352818/AWP_2_2020_Honkanen.pdf as ../pdfs/www.theseus.fi_handle_10024_352818.pdf
# skipping page 2 of ../pdfs/publications.bof.fi_handle_10024_52699.pdf: text would become too long
#
# converting ../metadata/serial-fin-train.jsonl to ../llm-dataset/serial-fin-train.jsonl
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_790074.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_506481.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_506481.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_506481.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_506481.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_506481.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_344412.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_344412.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_344412.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_344412.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_333172.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_333172.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_348392.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_503462.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_504382.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_504382.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_504382.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_504382.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_496449.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_493850.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_503162.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_45968.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/412096/Creathon_Hackathon.pdf as ../pdfs/www.theseus.fi_handle_10024_412096.pdf
# skipping page 2 of ../pdfs/www.julkari.fi_handle_10024_140595.pdf: text would become too long
# skipping page 4 of ../pdfs/www.julkari.fi_handle_10024_140595.pdf: text would become too long
# skipping page 6 of ../pdfs/www.julkari.fi_handle_10024_140595.pdf: text would become too long
#
# converting ../metadata/serial-swe-test.jsonl to ../llm-dataset/serial-swe-test.jsonl
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_185262.pdf: text would become too long
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_184354.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/333095/Karlsson_VBL03082019_Lat_havet.pdf as ../pdfs/www.theseus.fi_handle_10024_333095.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/333393/Dahlback_Frande__2019_Vaasa_insider_21062019.pdf as ../pdfs/www.theseus.fi_handle_10024_333393.pdf
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_333393.pdf: text would become too long
# skipping page 3 of ../pdfs/publications.bof.fi_handle_10024_45938.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_45938.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_45938.pdf: text would become too long
# skipping page 6 of ../pdfs/publications.bof.fi_handle_10024_45938.pdf: text would become too long
# skipping page 7 of ../pdfs/publications.bof.fi_handle_10024_45938.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/315289/Akerback_Oling_Warna_Engblom_2019_Vaasa_insider.pdf as ../pdfs/www.theseus.fi_handle_10024_315289.pdf
#
# converting ../metadata/serial-swe-train.jsonl to ../llm-dataset/serial-swe-train.jsonl
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_187234.pdf: text would become too long
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_184352.pdf: text would become too long
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_184336.pdf: text would become too long
# skipping page 2 of ../pdfs/publications.bof.fi_handle_10024_46419.pdf: text would become too long
# skipping page 3 of ../pdfs/publications.bof.fi_handle_10024_46419.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_46419.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_46419.pdf: text would become too long
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_184347.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_13141.pdf: text would become too long
# skipping page 3 of ../pdfs/osuva.uwasa.fi_handle_10024_11398.pdf: text would become too long
# skipping page 4 of ../pdfs/osuva.uwasa.fi_handle_10024_11398.pdf: text would become too long
# skipping page 2 of ../pdfs/www.doria.fi_handle_10024_184348.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/306684/Riesinger_2019_LF01022019_Kommentaren_ekologisk.pdf as ../pdfs/www.theseus.fi_handle_10024_306684.pdf
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_306684.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/359259/AU231220sid13.pdf as ../pdfs/www.theseus.fi_handle_10024_359259.pdf
# skipping page 1 of ../pdfs/www.theseus.fi_handle_10024_359259.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/303659/Andersson_2019_Relevans_Svangrum.pdf as ../pdfs/www.theseus.fi_handle_10024_303659.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/356424/Vattenforsorjning_paverkar_gasthamnarnas_verksamhet_Svangrum_10.2020.pdf as ../pdfs/www.theseus.fi_handle_10024_356424.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/405962/Soderholm-Emas_LF_9.10.2020.pdf as ../pdfs/www.theseus.fi_handle_10024_405962.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_405962.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/333217/Riesinger_LF_22032019_Konsten_att_odla_varoljevaxter.pdf as ../pdfs/www.theseus.fi_handle_10024_333217.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/307034/Vaaranmaa_Saatela_2019_3_ADHD_sa_mycket_mer_an.pdf as ../pdfs/www.theseus.fi_handle_10024_307034.pdf
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_307034.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_307034.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_307034.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_307034.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/324040/Ylitalo_2019_Vaasa_insider_Regionens_infraforetag.pdf as ../pdfs/www.theseus.fi_handle_10024_324040.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/356401/Antus_Penttinen_Ribacka_VBL_4.1.2020.pdf as ../pdfs/www.theseus.fi_handle_10024_356401.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/342688/SLS_Forsskahl.pdf as ../pdfs/www.theseus.fi_handle_10024_342688.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/333491/Katilolehti_3_2019.pdf as ../pdfs/www.theseus.fi_handle_10024_333491.pdf
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_333491.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_333491.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/333394/Vikfors_BErglund_2019_Svangrum_december.pdf as ../pdfs/www.theseus.fi_handle_10024_333394.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/345716/ViF_1_2020_36_40.pdf as ../pdfs/www.theseus.fi_handle_10024_345716.pdf
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_345716.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_345716.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_345716.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_345716.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/377549/Englund_Naturens_trafikant_VN_17.3.pdf as ../pdfs/www.theseus.fi_handle_10024_377549.pdf
# skipping page 3 of ../pdfs/publications.bof.fi_handle_10024_45942.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_45942.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_45942.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/374794/Vuorio_LOBAS_for_battre_ledarskap_Captain_2020.pdf as ../pdfs/www.theseus.fi_handle_10024_374794.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_374794.pdf: text would become too long
# skipping page 4 of ../pdfs/publications.bof.fi_handle_10024_45943.pdf: text would become too long
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_45943.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/495174/Nummela_mfl_Se_det_moderna_slaveriet_ViF_2021_1.pdf as ../pdfs/www.theseus.fi_handle_10024_495174.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_495174.pdf: text would become too long
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_495174.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_495174.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/356444/Karlsson_Svangrum_april.pdf as ../pdfs/www.theseus.fi_handle_10024_356444.pdf
# skipping page 5 of ../pdfs/publications.bof.fi_handle_10024_45977.pdf: text would become too long
# skipping page 6 of ../pdfs/publications.bof.fi_handle_10024_45977.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/356446/Wikberg_Att_foda_utan_radsla_Svangrum_augusti.pdf as ../pdfs/www.theseus.fi_handle_10024_356446.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/780385/Pikkuhiljaa_Raisa.pdf as ../pdfs/www.theseus.fi_handle_10024_780385.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/356465/Westerlund_Med_sjalvkannedom_VBL7.11.2020.pdf as ../pdfs/www.theseus.fi_handle_10024_356465.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/280473/Edelskold_Opinto_ohjaaja_4_2019.pdf as ../pdfs/www.theseus.fi_handle_10024_280473.pdf
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_280473.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/616010/Arcada_Publikation_1_2021.pdf as ../pdfs/www.theseus.fi_handle_10024_616010.pdf
# skipping page 2 of ../pdfs/www.julkari.fi_handle_10024_140799.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/333259/Bodbacka_Rak_2017_OT21022017_Samernas.pdf as ../pdfs/www.theseus.fi_handle_10024_333259.pdf
# skipping page 2 of ../pdfs/www.theseus.fi_handle_10024_333259.pdf: text would become too long
#
# converting ../metadata/thes-eng-test.jsonl to ../llm-dataset/thes-eng-test.jsonl
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_493464.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_493464.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_493464.pdf: text would become too long
# skipping page 2 of ../pdfs/taju.uniarts.fi_handle_10024_7552.pdf: text would become too long
# skipping page 2 of ../pdfs/www.utupub.fi_handle_10024_148800.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_6514.pdf: text would become too long
# skipping page 4 of ../pdfs/www.utupub.fi_handle_10024_148733.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/333888/Patrik Skog Creating and implementing a business process model.pdf as ../pdfs/www.theseus.fi_handle_10024_333888.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/354923/An analysis of Facebook posts.pdf as ../pdfs/www.theseus.fi_handle_10024_354923.pdf
#
# converting ../metadata/thes-eng-train.jsonl to ../llm-dataset/thes-eng-train.jsonl
# skipping page 4 of ../pdfs/www.doria.fi_handle_10024_181382.pdf: text would become too long
# skipping page 5 of ../pdfs/www.doria.fi_handle_10024_181382.pdf: text would become too long
# skipping page 4 of ../pdfs/www.utupub.fi_handle_10024_148977.pdf: text would become too long
# skipping page 5 of ../pdfs/www.utupub.fi_handle_10024_148977.pdf: text would become too long
# skipping page 6 of ../pdfs/www.utupub.fi_handle_10024_148977.pdf: text would become too long
# skipping page 7 of ../pdfs/www.utupub.fi_handle_10024_148977.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/498683/VIET NAM PLASTICS STRATEGY final fix(Autosaved) 2-compressed.pdf as ../pdfs/www.theseus.fi_handle_10024_498683.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/499187/Pre & Post-Operative Care in Bariatric Surgery.pdf as ../pdfs/www.theseus.fi_handle_10024_499187.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/339197/Mohammed Ali Mohammed Ali Thesis Final Version final.pdf as ../pdfs/www.theseus.fi_handle_10024_339197.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/501977/Bachelor Thesis Simon Hund .pdf as ../pdfs/www.theseus.fi_handle_10024_501977.pdf
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_501977.pdf: text would become too long
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_501977.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/499141/Kajoskoski_Kiira.pdf as ../pdfs/www.theseus.fi_handle_10024_499141.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/494691/A Creative Leader’s Impact on The Working Environment - Kim Forsander.pdf as ../pdfs/www.theseus.fi_handle_10024_494691.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/788457/Oberg_Andre.pdf as ../pdfs/www.theseus.fi_handle_10024_788457.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/344991/Pham Trang_Liquid Absorption_ver3.pdf as ../pdfs/www.theseus.fi_handle_10024_344991.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/501798/Nousiainen_Petri.pdf as ../pdfs/www.theseus.fi_handle_10024_501798.pdf
# skipping page 5 of ../pdfs/www.theseus.fi_handle_10024_501798.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_501798.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_501798.pdf: text would become too long
#
# converting ../metadata/thes-fin-test.jsonl to ../llm-dataset/thes-fin-test.jsonl
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7339.pdf: text would become too long
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_6858.pdf: text would become too long
# skipping page 3 of ../pdfs/www.utupub.fi_handle_10024_148896.pdf: text would become too long
# skipping page 5 of ../pdfs/trepo.tuni.fi_handle_10024_120535.pdf: text would become too long
# skipping page 6 of ../pdfs/trepo.tuni.fi_handle_10024_120535.pdf: text would become too long
# skipping page 7 of ../pdfs/trepo.tuni.fi_handle_10024_120535.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11334.pdf: text would become too long
# skipping page 4 of ../pdfs/trepo.tuni.fi_handle_10024_122802.pdf: text would become too long
# skipping page 5 of ../pdfs/www.utupub.fi_handle_10024_149211.pdf: text would become too long
# skipping page 6 of ../pdfs/www.utupub.fi_handle_10024_149211.pdf: text would become too long
# skipping page 7 of ../pdfs/www.utupub.fi_handle_10024_149211.pdf: text would become too long
#
# converting ../metadata/thes-fin-train.jsonl to ../llm-dataset/thes-fin-train.jsonl
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7419.pdf: text would become too long
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_7402.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_347788.pdf: text would become too long
# skipping page 3 of ../pdfs/trepo.tuni.fi_handle_10024_123112.pdf: text would become too long
# skipping page 3 of ../pdfs/trepo.tuni.fi_handle_10024_119937.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_483999.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_354490.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_354490.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_354490.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_336368.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_347710.pdf: text would become too long
# skipping page 4 of ../pdfs/trepo.tuni.fi_handle_10024_122901.pdf: text would become too long
# skipping page 5 of ../pdfs/trepo.tuni.fi_handle_10024_122901.pdf: text would become too long
# skipping page 6 of ../pdfs/trepo.tuni.fi_handle_10024_122901.pdf: text would become too long
# skipping page 3 of ../pdfs/www.utupub.fi_handle_10024_148801.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_6382.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_10826.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_10826.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_340884.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_340884.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_343939.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_343939.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_343939.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_409915.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_343735.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_374323.pdf: text would become too long
# skipping page 6 of ../pdfs/www.theseus.fi_handle_10024_374323.pdf: text would become too long
# skipping page 7 of ../pdfs/www.theseus.fi_handle_10024_374323.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/493531/Lehtonen_Enni.pdf as ../pdfs/www.theseus.fi_handle_10024_493531.pdf
#
# converting ../metadata/thes-swe-test.jsonl to ../llm-dataset/thes-swe-test.jsonl
# skipping page 3 of ../pdfs/taju.uniarts.fi_handle_10024_6498.pdf: text would become too long
# skipping page 5 of ../pdfs/osuva.uwasa.fi_handle_10024_11418.pdf: text would become too long
# skipping page 6 of ../pdfs/osuva.uwasa.fi_handle_10024_11418.pdf: text would become too long
# skipping page 7 of ../pdfs/osuva.uwasa.fi_handle_10024_11418.pdf: text would become too long
# skipping page 5 of ../pdfs/www.doria.fi_handle_10024_181091.pdf: text would become too long
# skipping page 6 of ../pdfs/www.doria.fi_handle_10024_181091.pdf: text would become too long
# skipping page 7 of ../pdfs/www.doria.fi_handle_10024_181091.pdf: text would become too long
# skipping page 5 of ../pdfs/www.doria.fi_handle_10024_180950.pdf: text would become too long
# skipping page 6 of ../pdfs/www.doria.fi_handle_10024_180950.pdf: text would become too long
# skipping page 7 of ../pdfs/www.doria.fi_handle_10024_180950.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/271532/Etzell_Emilia.pdf as ../pdfs/www.theseus.fi_handle_10024_271532.pdf
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_271532.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/498793/Eklund_Liz_Marjanen_Emma.pdf as ../pdfs/www.theseus.fi_handle_10024_498793.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/339015/Kahrimanovic_Arnel_Mesic_Selma.pdf as ../pdfs/www.theseus.fi_handle_10024_339015.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/500108/Examensarbete Tobias Wargh_Theseus.pdf as ../pdfs/www.theseus.fi_handle_10024_500108.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/752810/Uzelac-Varda_Silvija_Zvidrina_Arita.pdf as ../pdfs/www.theseus.fi_handle_10024_752810.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/497790/Skoglund_Wilhelm.pdf as ../pdfs/www.theseus.fi_handle_10024_497790.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/354673/Madeleine_Kozma.pdf as ../pdfs/www.theseus.fi_handle_10024_354673.pdf
#
# converting ../metadata/thes-swe-train.jsonl to ../llm-dataset/thes-swe-train.jsonl
# skipping page 4 of ../pdfs/taju.uniarts.fi_handle_10024_6874.pdf: text would become too long
# skipping page 5 of ../pdfs/taju.uniarts.fi_handle_10024_6874.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/497693/Akerlund_Axel.pdf as ../pdfs/www.theseus.fi_handle_10024_497693.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/355610/Gulbrandsen_Thoralf.pdf as ../pdfs/www.theseus.fi_handle_10024_355610.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/336844/IdaTallgren.pdf as ../pdfs/www.theseus.fi_handle_10024_336844.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/498406/Haglund_Andre.pdf as ../pdfs/www.theseus.fi_handle_10024_498406.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/496477/Aberg_Jacob.pdf as ../pdfs/www.theseus.fi_handle_10024_496477.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/347800/Goodyear_Ann-Christine.pdf as ../pdfs/www.theseus.fi_handle_10024_347800.pdf
# skipping page 3 of ../pdfs/www.theseus.fi_handle_10024_347800.pdf: text would become too long
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_347800.pdf: text would become too long
# wrote https://www.theseus.fi/bitstream/handle/10024/341665/Haggblom_Daniel.pdf as ../pdfs/www.theseus.fi_handle_10024_341665.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/347567/Kjellman_Hannah.pdf as ../pdfs/www.theseus.fi_handle_10024_347567.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/787930/Ukkonen.Martin.pdf as ../pdfs/www.theseus.fi_handle_10024_787930.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/494336/Examensarbete Återupplivningstemadag Sirviö Wickström.pdf as ../pdfs/www.theseus.fi_handle_10024_494336.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/339776/Ganner_Alina,Fredriksson_Dan.pdf as ../pdfs/www.theseus.fi_handle_10024_339776.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/497852/Granstrom_Tim.pdf as ../pdfs/www.theseus.fi_handle_10024_497852.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/354664/Myrberg_Kristoffer_ExArb_Arcada.pdf as ../pdfs/www.theseus.fi_handle_10024_354664.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/804322/Anne-Sundstrom_Sarah_Hagglund.pdf as ../pdfs/www.theseus.fi_handle_10024_804322.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/347596/High Fashion the High Street way - Examensarbete - Julia Andersson.pdf as ../pdfs/www.theseus.fi_handle_10024_347596.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/494334/Barnmorskors uppfattning om en normal förlossning. En scoping review.pdf as ../pdfs/www.theseus.fi_handle_10024_494334.pdf
# wrote https://www.theseus.fi/bitstream/handle/10024/339424/Barn med risk för marginalisering Ett beställningsarbete av Barnvänlig kommun i Raseborg.pdf as ../pdfs/www.theseus.fi_handle_10024_339424.pdf
# skipping page 4 of ../pdfs/www.theseus.fi_handle_10024_339424.pdf: text would become too long

# %% [markdown]
# # Fine tune Zephyr-7B model using Ludwig framework
#
# See requirements.txt for dependencies. The main dependency is `ludwig[llm]`
#
# Based on these sources:
# * https://ludwig.ai/latest/getting_started/llm_finetuning/
# * https://ludwig.ai/latest/user_guide/llms/finetuning/
# * https://colab.research.google.com/drive/1Ly01S--kUwkKQalE-75skalp-ftwl0fE?usp=sharing
# * https://predibase.com/blog/fine-tuning-mistral-7b-on-a-single-gpu-with-ludwig
# * https://levelup.gitconnected.com/no-more-hard-coding-use-declarative-configuration-to-build-and-fine-tune-custom-llms-on-your-data-6418b243fad7
# * https://predibase.com/blog/fine-tuning-zephyr-7b-to-analyze-customer-support-call-logs
# * https://colab.research.google.com/drive/1nX6hd4P_oc-ByaJLNXiryJyMdfEmmBJ0?usp=sharing#scrollTo=fd_LA_2Wx_qr

# %%
# Load and prepare fine-tuning dataset

import json
import glob
import pandas as pd

train_files = glob.glob("../../llm-dataset/*-train.jsonl")
test_files = glob.glob("../../llm-dataset/*-test.jsonl")

KEEP_FIELDS = {
    'dc.contributor.author',
    'dc.date.issued',
    'dc.identifier.isbn',
    'dc.language.iso',
    'dc.publisher',
    'dc.relation.eissn',
    'dc.title'    
}
MAX_TEXT_LENGTH = 3072

def preprocess_sample(sample):
    # subset & JSON encode the ground truth
    subset = {key: val
              for key, val in sample["ground_truth"].items()
              if key in KEEP_FIELDS}
    sample["ground_truth"] = subset
    sample["ground_truth_json"] = json.dumps(subset)
    sample["text"] = sample["text"][:MAX_TEXT_LENGTH]
    del sample["metadata"]
    del sample["id"]
    del sample["url"]
    return sample

def dataset_to_df(files):
    records = []
    for filename in files:
        with open(filename) as infile:
            for line in infile:
                sample = json.loads(line)
                records.append(preprocess_sample(sample))
    return pd.DataFrame.from_records(records)

train_df = dataset_to_df(train_files)
test_df = dataset_to_df(test_files)
print(train_df.shape, test_df.shape)
print(train_df.keys())

model = None  # placeholder
# Out:
# (556, 3) (167, 3)
# Index(['text', 'ground_truth', 'ground_truth_json'], dtype='object')

# %%
# workaround for bitsandbytes bug https://github.com/TimDettmers/bitsandbytes/issues/675

import os

if "SLURM_SUBMIT_DIR" in os.environ:
    del os.environ["SLURM_SUBMIT_DIR"]

# %% [markdown]
# # Finetuning
#
# Finetuning specific code starts here, skip to Inference if you have a fine-tuned model and want to use that

# %%
import yaml

config_str = """
model_type: llm
base_model: HuggingFaceH4/zephyr-7b-beta

quantization:
  bits: 4

adapter:
  type: lora

prompt:
  template: |
    ### Instruction:
    Extract metadata from the following document. Return as JSON.

    ### Input:
    {text}

    ### Response:

input_features:
  - name: text
    type: text
    preprocessing:
      max_sequence_length: 2048

output_features:
  - name: ground_truth_json
    type: text
    preprocessing:
      max_sequence_length: 1024

trainer:
  type: finetune
  learning_rate: 0.0002
  batch_size: 1
  gradient_accumulation_steps: 16
  enable_gradient_checkpointing: true
  epochs: 3
  learning_rate_scheduler:
    decay: cosine
    warmup_fraction: 0.03
    reduce_on_plateau: 0

preprocessing:
  sample_ratio: 1.0

generation:
  temperature: 0.1
  max_new_tokens: 1024
"""

config = yaml.safe_load(config_str)

# %%
import logging
from ludwig.api import LudwigModel

model = LudwigModel(config=config, logging_level=logging.INFO)
results = model.train(training_set=train_df, test_set=test_df)

# %%
# Save the model
model.save("finetuned-model")

# %% [markdown]
# # Inference
#
# You can start running the notebook from here if you already have fine-tuned a model in a previous session!
#
# **Note:** you still need to load the datasets above and run the bitsandbytes workaround

# %%
# If no model exists, load the previously fine-tuned model

import logging
from ludwig.api import LudwigModel

if model is None:
    model = LudwigModel.load("finetuned-model", logging_level=logging.INFO)

# %%
# %%time
# Inference using the trained model

def batch(iterable, n=1):
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]

# We need two do this in separate batches, otherwise the kernel gets killed (GPU OOM?)
test_pred_batches = []
for test_batch in batch(test_df, 32):
    test_pred_batches.append(model.predict(test_batch, batch_size=16)[0])

# merge the prediction batches into a single dataframe
test_preds = pd.concat(test_pred_batches)
# Out:
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Prediction: 100%|██████████| 2/2 [03:35<00:00, 107.72s/it]
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Finished predicting in: 217.53s.
# /wrk-vakka/users/oisuomin/git/FinGreyLit/experiments/ludwig-finetune-llm/venv/lib/python3.11/site-packages/ludwig/features/feature_utils.py:102: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(sequence_probabilities))
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Prediction: 100%|██████████| 2/2 [04:23<00:00, 131.90s/it]
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Finished predicting in: 265.45s.
# /wrk-vakka/users/oisuomin/git/FinGreyLit/experiments/ludwig-finetune-llm/venv/lib/python3.11/site-packages/ludwig/features/feature_utils.py:102: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(sequence_probabilities))
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Prediction: 100%|██████████| 2/2 [04:40<00:00, 140.42s/it]
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Finished predicting in: 282.45s.
# /wrk-vakka/users/oisuomin/git/FinGreyLit/experiments/ludwig-finetune-llm/venv/lib/python3.11/site-packages/ludwig/features/feature_utils.py:102: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(sequence_probabilities))
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Prediction: 100%|██████████| 2/2 [04:28<00:00, 134.46s/it]
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Finished predicting in: 270.65s.
# /wrk-vakka/users/oisuomin/git/FinGreyLit/experiments/ludwig-finetune-llm/venv/lib/python3.11/site-packages/ludwig/features/feature_utils.py:102: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(sequence_probabilities))
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Prediction: 100%|██████████| 2/2 [04:12<00:00, 126.46s/it]
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Finished predicting in: 254.58s.
# /wrk-vakka/users/oisuomin/git/FinGreyLit/experiments/ludwig-finetune-llm/venv/lib/python3.11/site-packages/ludwig/features/feature_utils.py:102: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(sequence_probabilities))
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Prediction: 100%|██████████| 1/1 [00:40<00:00, 40.11s/it]
# Loaded HuggingFace implementation of HuggingFaceH4/zephyr-7b-beta tokenizer
# Finished predicting in: 41.12s.
# CPU times: user 21min 54s, sys: 20.1 s, total: 22min 14s
# Wall time: 22min 11s
# /wrk-vakka/users/oisuomin/git/FinGreyLit/experiments/ludwig-finetune-llm/venv/lib/python3.11/site-packages/ludwig/features/feature_utils.py:102: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(sequence_probabilities))

# %%
with open('test-records.jsonl', 'w') as outfile:
    for ground_truth, prediction in zip(test_df['ground_truth_json'], test_preds['ground_truth_json_response']):
        print(f"Ground Truth:\n{ground_truth}")
        print(f"Prediction:\n{prediction[0]}\n")
        ground_truth = json.loads(ground_truth)
        try:
            prediction = json.loads(prediction[0])
        except json.JSONDecodeError:
            prediction = {}
        # rowid is set to unknown as we've lost it somewhere along the way...
        record = {"ground_truth": ground_truth, "prediction": prediction, "rowid": "unknown"}
        json.dump(record, outfile)
        outfile.write("\n")
# Out:
# Ground Truth:
# {"dc.title": "Poliisikoulutuksen vaikuttavuusarviointi 2021 : vuosina 2018-2019 valmistuneiden poliisien ty\u00f6llisyys ja arviot koulutuksen ty\u00f6el\u00e4m\u00e4vastaavuudesta", "dc.contributor.author": ["Vuorensyrj\u00e4, Matti"], "dc.date.issued": "2021", "dc.identifier.isbn": ["978-951-815-386-6"], "dc.language.iso": "fin", "dc.publisher": ["Poliisiammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Poliisikoulutuksen vaikuttavuusarviointi 2021 sisus POAMK", "dc.contributor.author": ["Vuorensyrj\u00e4, Matti"], "dc.date.issued": "2021", "dc.identifier.isbn": ["978-951-815-386-6"], "dc.language.iso": "fin", "dc.publisher": ["Poliisiammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "FAQ : Taiteen digitaaliset toimintaymp\u00e4rist\u00f6t", "dc.date.issued": "2018", "dc.identifier.isbn": ["978-952-7266-07-6"], "dc.language.iso": "fin", "dc.publisher": ["Tampereen ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Taiteen digitaaliset toimintaymp\u00e4rist\u00f6t 2018 : FAQ", "dc.date.issued": "2018", "dc.relation.eissn": "1456-002X", "dc.identifier.isbn": ["978-952-7266-07-6"], "dc.language.iso": "fin", "dc.publisher": ["Tampereen ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "BOFIT Ven\u00e4j\u00e4-ennuste 2019-2021", "dc.date.issued": "2019-10-03", "dc.language.iso": "fin", "dc.publisher": ["Suomen Pankki"]}
# Prediction:
# {"dc.title": "BOFIT Ven\u00e4j\u00e4-ennuste 2019-2021", "dc.contributor.author": ["BOFIT Ven\u00e4j\u00e4-ryhm\u00e4"], "dc.date.issued": "2019-10-03", "dc.language.iso": "fin"}
#
# Ground Truth:
# {"dc.title": "Ammattikielisten tekstien tutkimisesta - esimerkkin\u00e4 tilintarkastuskertomus", "dc.contributor.author": ["Katajam\u00e4ki, Heli", "Koskela, Merja"], "dc.date.issued": "2012", "dc.identifier.isbn": ["978-952-5446-72-2"], "dc.language.iso": "fin", "dc.publisher": ["Kotimaisten kielten keskus"]}
# Prediction:
# {"dc.title": "Ammattikielisten tekstien tutkimisesta : esimerkkin\u00e4 tilintarkastuskertomus", "dc.contributor.author": ["Koskela, Merja", "Katajam\u00e4ki, Heli"], "dc.date.issued": "2012", "dc.language.iso": "fin", "dc.publisher": ["Kotimaisten kielten keskus"]}
#
# Ground Truth:
# {"dc.title": "Hahmottamisen laaja-alaisuus ja tiedon luonne", "dc.contributor.author": ["Sepp\u00e4l\u00e4, Mikael"], "dc.date.issued": "2022", "dc.language.iso": "fin", "dc.publisher": ["Tietojohtaminen"]}
# Prediction:
# {"dc.title": "Hahmottamisen laaja-alaisuus ja tiedon luonne", "dc.contributor.author": ["Sepp\u00e4l\u00e4, Mikael"], "dc.date.issued": "2022", "dc.language.iso": "fin", "dc.publisher": ["Tieto- ja kulttuurinopimislapsi ry"]}
#
# Ground Truth:
# {"dc.title": "Kansalliset keskuspankit tuntevat oman maansa markkinapaikat", "dc.contributor.author": ["Hievanen, Laura"], "dc.date.issued": "2015-02-02", "dc.language.iso": "fin", "dc.publisher": ["Suomen Pankki"]}
# Prediction:
# {"dc.title": "First North Bond Market Finland", "dc.date.issued": "2016", "dc.language.iso": "fin", "dc.publisher": ["NASDAQ OMX"]}
#
# Ground Truth:
# {"dc.title": "Opiskelija keikkaty\u00f6n kiemuroissa", "dc.contributor.author": ["Pajula, Carolina"], "dc.date.issued": "2019", "dc.identifier.isbn": ["978-952-7266-39-7"], "dc.language.iso": "fin", "dc.publisher": ["Tampereen ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Opiskelija keikkaty\u00f6n kiemuroissa", "dc.contributor.author": ["Pajula, Christina"], "dc.date.issued": "2019", "dc.identifier.isbn": ["978-952-395-119-6"], "dc.language.iso": "fin", "dc.publisher": ["Tampereen ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Musiikkikasvatus vsk. 17 nro. 2 (2014)", "dc.date.issued": "2014", "dc.relation.eissn": "2342-1150", "dc.language.iso": "fin", "dc.publisher": ["Sibelius-Akatemia, Taideyliopisto, Musiikkikasvatuksen, jazzin ja kansanmusiikin osasto", "Suomen Taidekasvatuksen Tutkimusseura"]}
# Prediction:
# {"dc.title": "Musiikkikasvatus : The Finnish Journal of Music Education", "dc.date.issued": "2014", "dc.language.iso": "eng", "dc.publisher": ["Sibelius-Akatemia, Taideyliopisto"]}
#
# Ground Truth:
# {"dc.title": "Oluenarviointisovellukset \u2013 olutskenen siunaus vai kirous", "dc.contributor.author": ["Lehtinen, Anik\u00f3"], "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Olutposti Media"]}
# Prediction:
# {"dc.title": "Oluenarviointisovellukset \u2013 olutskenen siunaus vai kirous", "dc.contributor.author": ["Lehtinen, Anikko"], "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Olutposti"]}
#
# Ground Truth:
# {"dc.title": "TARU-SANOMAT", "dc.date.issued": "2021", "dc.relation.eissn": "2490-2055", "dc.identifier.isbn": ["978-952-328-324-4"], "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Taru-sanomat : Tarinateatteri ja taiteelliset menetelm\u00e4 opetuksessa", "dc.contributor.author": ["Rahmel, P\u00e4ivi"], "dc.date.issued": "2021-12-17", "dc.identifier.isbn": ["978-952-328-324-4"], "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Ymp\u00e4rist\u00f6vaikutusten arviointi 80-luvun liikerakennuksen kiinteist\u00f6kehitt\u00e4misess\u00e4 : Elinkaariarvioinnin (LCA), elinkaarikustannusten (LCC) ja energiasimuloinnin arviointiraportti", "dc.contributor.author": ["Keskisalo, Mika", "Kuusisto, Jari", "Matveinen, Mikko"], "dc.date.issued": "2022", "dc.relation.eissn": "2323-6914", "dc.identifier.isbn": ["978-952-275-365-6"], "dc.language.iso": "fin", "dc.publisher": ["Karelia-ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Ymp\u00e4rist\u00f6vaikutusten arviointi 80-luvun liikerakennuksen kiinteist\u00f6kehitt\u00e4misess\u00e4", "dc.date.issued": "2022", "dc.identifier.isbn": ["978-952-275-365-6"], "dc.language.iso": "fin", "dc.publisher": ["Karelia-ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "IMF ennustaa talouskasvua euroalueelle ja Suomelle", "dc.contributor.author": ["Toivanen, Mervi"], "dc.date.issued": "2015-04-15", "dc.language.iso": "fin"}
# Prediction:
# {"dc.title": "Eurotalouden kasvu ennustetaan positiivisemm\u00e4kki", "dc.contributor.author": ["Korhonen, Jukka"], "dc.date.issued": "2016-06-08", "dc.language.iso": "fin", "dc.publisher": ["Suomen Pankki"]}
#
# Ground Truth:
# {"dc.title": "Terveydenhoitajan ammatilliset osaamisvaatimukset", "dc.contributor.author": ["Haarala, P\u00e4ivi"], "dc.date.issued": "2022", "dc.relation.eissn": "2669-8021", "dc.identifier.isbn": ["978-952-328-341-1"], "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Terveydenhoitajan ammatilliset osaamisvaatimukset", "dc.contributor.author": ["Haarala, P\u00e4ivi"], "dc.date.issued": "2022-03-18", "dc.identifier.isbn": ["978-952-328-341-1"], "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Medianomit ehk\u00e4isev\u00e4t ennalta ty\u00f6tt\u00f6myytt\u00e4", "dc.contributor.author": ["Karppinen, Anneli", "Ketonen, Emma"], "dc.date.issued": "2019-03-12", "dc.language.iso": "fin", "dc.publisher": ["Tampereen ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Medianomit ehk\u00e4isev\u00e4t ennalta ty\u00f6tt\u00f6myytt\u00e4", "dc.contributor.author": ["Karppinen, Anneli", "Ketonen, Emma"], "dc.date.issued": "2019-03-12", "dc.language.iso": "fin", "dc.publisher": ["Tampereen ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Huomioi toimintarajoitteiset lapset ja nuoret hyvinvointikertomuksessa", "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["THL"]}
# Prediction:
# {"dc.title": "Huomioi toimintarajoitteiset lapset ja nuoret hyvinvointikertomuksessa", "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["THL"]}
#
# Ground Truth:
# {"dc.title": "Lohkoketjuteknologian massa-adoption mahdollisuutta tutkimassa", "dc.contributor.author": ["Honkanen, Petri"], "dc.date.issued": "2020", "dc.relation.eissn": "2342-3064", "dc.identifier.isbn": ["978-952-7365-09-0"], "dc.language.iso": "fin", "dc.publisher": ["Yrkesh\u00f6gskolan Arcada"]}
# Prediction:
# {"dc.title": "Lohkoketjuteknologian massa-adoption mahdollisuutta tutkimassa", "dc.contributor.author": ["Honkanen, Petri"], "dc.date.issued": "2020-12-07", "dc.identifier.isbn": ["978-952-7365-09-0"], "dc.language.iso": "fin", "dc.publisher": ["Yrkesh\u00f6gskolan Arcada"]}
#
# Ground Truth:
# {"dc.title": "Eduskunnan pankkivaltuuston kertomus Eduskunnalle 2013", "dc.date.issued": "2014-06-10", "dc.language.iso": "fin", "dc.publisher": ["Edita Prima Oy"]}
# Prediction:
# {"dc.title": "Eduskunnan pankkivaltuuston kertomus 2013", "dc.date.issued": "2014", "dc.relation.eissn": "1796-9794", "dc.identifier.isbn": ["978-952-244-875-8"], "dc.language.iso": "fin", "dc.publisher": ["Editaprima Oy"]}
#
# Ground Truth:
# {"dc.title": "Johtokunnan kertomus pankkivaltuustolle Finanssivalvonnan toiminnasta 2022", "dc.date.issued": "2023-03-20", "dc.language.iso": "fin"}
# Prediction:
# {"dc.title": "Johtokunnan kertomus pankkivaltuustolle Finanssivalvonnan toiminnasta 2022", "dc.date.issued": "2023-03-17", "dc.language.iso": "fin", "dc.publisher": ["Finanssivalvonta"]}
#
# Ground Truth:
# {"dc.title": "Kest\u00e4v\u00e4n j\u00e4tehuollon koulutusosaamista vahvistamassa Ven\u00e4j\u00e4ll\u00e4 ja Kazakstanissa", "dc.contributor.author": ["Asikainen, Eveliina", "Kallio, Ella"], "dc.date.issued": "2020", "dc.identifier.isbn": ["978-952-7266-42-7"], "dc.language.iso": "fin", "dc.publisher": ["Tampereen ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Kest\u00e4v\u00e4n j\u00e4tehuollon koulutusosaamista vahvistamassa Ven\u00e4j\u00e4ll\u00e4 ja Kazakstanissa", "dc.contributor.author": ["Asikainen, Eveliina", "Kallio, Ella"], "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Tampereen ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Monimuotoinen ansioty\u00f6 : N\u00e4k\u00f6kulmia monista l\u00e4hteist\u00e4 ansaintaan", "dc.date.issued": "2022", "dc.identifier.isbn": ["978-952-359-040-3"], "dc.language.iso": "fin", "dc.publisher": ["Tampere University Press"]}
# Prediction:
# {"dc.title": "Monimuotoinen ansioty\u00f6 : N\u00e4k\u00f6kulmia monista l\u00e4hteist\u00e4 ansaintaan", "dc.contributor.author": ["J\u00e4rvensivu, Anu", "Haapakorpi, Arja"], "dc.date.issued": "2022", "dc.identifier.isbn": ["978-952-359-040-3"], "dc.language.iso": "fin", "dc.publisher": ["Tampere University Press"]}
#
# Ground Truth:
# {"dc.title": "Osuma-peli \u2013 Innostusta yhteiskehittelyyn!", "dc.contributor.author": ["Halonen, Katri", "Salmenkangas, Mai", "Wallin, Riikka"], "dc.date.issued": "2019", "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Osuma-peli : Innostusta yhteiskehittelyyn!", "dc.contributor.author": ["Halonen, Katri", "Salmenkangas, Mai", "Wallin, Riikka"], "dc.date.issued": "2019", "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Loppuraportti Koliikkivauvojen hoito vy\u00f6hyketerapialla -pilottitutkimus 2017-2019", "dc.contributor.author": ["Hannula, Leena", "M\u00e4kij\u00e4rvi, Markku"], "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Luonnonl\u00e4\u00e4ketieteen Keskusliitto LKL ry"]}
# Prediction:
# {"dc.title": "Loppuraportti Koliikkivauvojen hoito vy\u00f6hyketerapialla -pilottitutkimus 2017-2019", "dc.contributor.author": ["Hannula, Leena", "M\u00e4kij\u00e4rvi, Markku"], "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Luonnonl\u00e4\u00e4ketieteen keskusliitto"]}
#
# Ground Truth:
# {"dc.title": "Karelia.fi - Karelia-ammattikorkeakoulun tutkimus- ja kehitt\u00e4mistoimintaa EU-ohjelmakaudella 2014-2020", "dc.date.issued": "2021", "dc.language.iso": "fin", "dc.publisher": ["Karelia-Ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Karelia.fi : Karelia-ammattikorkeakoulun tutkimus- ja kehitt\u00e4mistoiminta EU-ohjelmakaudella 2014-2020", "dc.date.issued": "2021", "dc.language.iso": "fin", "dc.publisher": ["Karelia-ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Julkisen tilan taiteen tilasta. Puheenvuoroja julkisen taiteen konteksteista", "dc.date.issued": "2021", "dc.identifier.isbn": ["978-952-353-410-0"], "dc.language.iso": "fin", "dc.publisher": ["Taideyliopisto"]}
# Prediction:
# {"dc.title": "Julkisen taide ja uudet teknologiat : Ymp\u00e4rist\u00f6taide ja pienet paikkakunnat", "dc.date.issued": "2021", "dc.identifier.isbn": ["978-952-353-410-0"], "dc.language.iso": "fin", "dc.publisher": ["Taideyliopisto"]}
#
# Ground Truth:
# {"dc.title": "Kehitt\u00e4misty\u00f6st\u00e4 oivalluksia  Kulttuurituotanto (ylempi AMK) tutkinnon opinn\u00e4ytety\u00f6n opas", "dc.contributor.author": ["Halonen, Katri"], "dc.date.issued": "2022", "dc.identifier.isbn": ["978-952-328-354-1"], "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Kehitt\u00e4misty\u00f6st\u00e4 oivallukset : Kulttuurituotannon (ylempi AMK) tutkinnon opinn\u00e4ytety\u00f6n opas", "dc.date.issued": "2022", "dc.identifier.isbn": ["978-952-328-354-1"], "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Kehitt\u00e4misty\u00f6st\u00e4 oivalluksia. Kulttuurituotanto (ylempi AMK) tutkinnon opinn\u00e4ytety\u00f6n opas \u2013 Kulttuurituotannon ty\u00f6papereita. 2. painos", "dc.contributor.author": ["Halonen, Katri"], "dc.date.issued": "2021", "dc.identifier.isbn": ["978-952-328-310-7"], "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Kehitt\u00e4miisty\u00f6st\u00e4 oivalluksi", "dc.contributor.author": ["Halonen, Katri"], "dc.date.issued": "2021", "dc.identifier.isbn": ["978-952-328-310-7"], "dc.language.iso": "fin", "dc.publisher": ["Metropolia Ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Pk-yritysten liiketoiminnan muotoilun CookBook", "dc.contributor.author": ["Jaakola, Hanna", "Pietik\u00e4inen, Minna", "Rinta-Jouppi, Laura", "Viljanen, Jenni"], "dc.date.issued": "2021", "dc.identifier.isbn": ["978-951-799-605-1"], "dc.language.iso": "fin", "dc.publisher": ["Laurea-ammattikorkeakoulu"]}
# Prediction:
# {"dc.title": "Liiketoiminnan muotoilun CookBook", "dc.date.issued": "2021", "dc.identifier.isbn": ["978-951-799-605-1"], "dc.language.iso": "fin", "dc.publisher": ["Laurea-ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Suomen Pankki 200 vuotta II: Parlamentin pankki", "dc.contributor.author": ["Kuuster\u00e4, Antti", "Tarkka, Juha"], "dc.date.issued": "2012-01-11", "dc.identifier.isbn": ["978-951-1-24272-7"], "dc.language.iso": "fin", "dc.publisher": ["Otava"]}
# Prediction:
# {"dc.title": "Suomen Pankki 200 vuotta parlamentin pankki", "dc.date.issued": "2014", "dc.identifier.isbn": ["978-951-1-24272-7"], "dc.language.iso": "fin", "dc.publisher": ["Helsingin kansanliitto"]}
#
# Ground Truth:
# {"dc.title": "Terveytt\u00e4 edist\u00e4v\u00e4 liikunta Etel\u00e4-Savon kunnissa 2020", "dc.date.issued": "2020-12-04", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "TEAviisari : Terveytt\u00e4 edist\u00e4v\u00e4 liikunta : Etel\u00e4-Savon kunnissa 2020", "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
#
# Ground Truth:
# {"dc.title": "L\u00e4\u00e4kehoidon tiedonhallinnan konsepti", "dc.contributor.author": ["Virkkunen, Heikki", "Relander, Toni", "Malmivaara, Antti", "Hiltunen, Piritta", "Jalonen, Marko", "N\u00e4rv\u00e4nen, Jarkko"], "dc.date.issued": "2020-06", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "L\u00e4\u00e4kehoidon tiedonhallinnan konsepti", "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
#
# Ground Truth:
# {"dc.title": "Koronaepidemian vaikutukset hyvinvointiin, palveluihin ja talouteen (2020)", "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "Koronaepidemian vaikutukset hyvinvointiin, palveluihin ja talouteen : THL:n seurantaraportti, viikot 49-50/2020", "dc.date.issued": "2020-12-16", "dc.language.iso": "fin", "dc.publisher": ["THL"]}
#
# Ground Truth:
# {"dc.title": "Fyysisen toimintakyvyn mittaaminen ja arviointi v\u00e4est\u00f6tutkimuksissa", "dc.contributor.author": ["Sainio, P\u00e4ivi", "Valkeinen, Heli", "Stenholm, Sari", "Vaara, Mariitta", "Rinne, Marjo"], "dc.date.issued": "2020-09-29", "dc.language.iso": "fin", "dc.publisher": ["TOIMIA"]}
# Prediction:
# {"dc.title": "Fyysisen toimintakyvyn mittaaminen ja arviointi \u00e4\u00e4nest\u00f6tutkimuksissa", "dc.contributor.author": ["Koivum\u00e4ki, Sanna"], "dc.date.issued": "2020-09-29", "dc.identifier.isbn": ["978-952-7264-76-7"], "dc.language.iso": "fin", "dc.publisher": ["Taiteen ja tieteen korkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Terveytt\u00e4 edist\u00e4v\u00e4 liikunta Pohjois-Karjalan kunnissa 2020", "dc.date.issued": "2020-12-04", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "Terveytt\u00e4 edist\u00e4v\u00e4 liikunta Pohjois-Karjalan kunniissa 2020 : Liikunnan edist\u00e4misaktiivisuus Suomen kunnissa TEAviisari 2020 -tiedonkeruussa", "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
#
# Ground Truth:
# {"dc.title": "Suun terveydenhuollon toiminnalliset m\u00e4\u00e4rittelyt", "dc.contributor.author": ["Aalto, Anna", "Virkkunen, Heikki", "Turunen, Seppo", "Saarela, Hanna-Leena"], "dc.date.issued": "2020-04", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "Suun terveydenhuollon potilaskertomusmerkint\u00f6jen toiminnalliset m\u00e4\u00e4rittelyt", "dc.contributor.author": ["Aalto, Anna", "Virkkunen, Heikki", "Turunen, Seppo", "Saarela, Hanna-Leena", "R\u00e4ty, Tarja"], "dc.date.issued": "2020", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
#
# Ground Truth:
# {"dc.title": "Hoidon tarpeen arviointi : nykytilan selvitys", "dc.contributor.author": ["Saukkonen, Sanna-Mari", "\u00c5lander, Anne"], "dc.date.issued": "2021-06", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "Hoidon tarpeen arvioinnin nykytilan selvitys", "dc.contributor.author": ["Saukkonen, Sanna-Mari", "Alander, Anne"], "dc.date.issued": "2021-07-02", "dc.language.iso": "fin", "dc.publisher": ["Terveyden ja hyvinvoinnin laitos"]}
#
# Ground Truth:
# {"dc.title": "Monitorering av biofilmbildningen med kvartskristallmikrobalans (QCM) och ytplasmonresonans (SPR)", "dc.contributor.author": ["Holmstr\u00f6m, Ellinoora"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2023", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Monitorering av biofilmbildning med kvartskristallmikrobalans (QCM) och ytplasmonresonans (SPR)", "dc.contributor.author": ["Holmstr\u00f6m, Ellinoora"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2023", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "Resultatmanipulering : En studie om f\u00f6ruts\u00e4ttningarna p\u00e5 den finska marknaden", "dc.contributor.author": ["Lindqvist, Robert"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021-05-17", "dc.language.iso": "swe"}
# Prediction:
# edda direktörer;
# Ndep = ny direktörer;
# Ndep_TAC = avskedda direktörer + ny direktörer;
# Ndep_NDAC = ny direktörer - avskedda direktörer;
# Ndep_NDAC_TAC = ny direktörer - avskedda direktörer - totala periodiseringar;
# Ndep_NDAC_TAC_Dep = ny direktörer - avskedda direktörer - totala periodiseringar - avskedda direktörer;
# Ndep_NDAC_TAC_Dep_Ndep_TAC = ny direktörer - avskedda direktörer - totala periodiseringar - avskedda direktörer - ny direktörer;
# Ndep_NDAC_TAC_Dep_Ndep_TAC_Dep_Ndep = ny direktörer - avskedda direktörer - totala periodiseringar - avskedda direktörer - ny direktörer - avskedda direktörer - ny direktörer;
# Ndep_NDAC_TAC_Dep_Ndep_TAC_Dep_Ndep_Dep = ny direktörer - avskedda direktörer - totala periodiseringar - avskedda direktörer - ny direktörer - avskedda direktörer - ny direktörer - avskedda direktörer;
#  {"dc.title": "Resultatmanipulering : En studie om f\u00f6ruts\u00e4ndningarna p\u00e5 den finska marknaden", "dc.contributor.author": ["Lindqvist, Robert"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021-05-27", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "Naturliga, rytmiska och holistiska individer : Diskurser om pedagogik i Waldorfskolor i Sverige", "dc.contributor.author": ["Jansson, Charlotte Marie"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2022", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Naturliga, rytmiska och holistiska individer : Diskurser om pedagogik i Waldorfskolor i Sverige", "dc.contributor.author": ["Jansson, Charlotte"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2022", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "Musik och r\u00f6relse som plattform f\u00f6r kreativitet : en intervjustudie med fyra musikl\u00e4rare i \u00e5rskurserna 7-9", "dc.contributor.author": ["Henriksson, Amanda"], "dc.publisher": ["Taideyliopiston Sibelius-Akatemia"], "dc.date.issued": "2015", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Musik och r\u00f6relse som plattform f\u00f6r kreativitet : En intervjustudie med fyra l\u00e4rare i \u00e5rskurserna 7-79", "dc.contributor.author": ["Henriksson, Amanda"], "dc.publisher": ["Sibelius-Akademin"], "dc.date.issued": "2015", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "H\u00f6gstadieelevers s\u00f6mn- och kostvanor \u00f6ver tid", "dc.contributor.author": ["Backlund, Emma", "\u00c5kerlund, Hanna"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "H\u00f6gstadieelevers s\u00f6mn- och kostvanor \u00f6ver tid", "dc.contributor.author": ["Backlund, Emma", "Åkerlund, Hanna"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "Inskolningens och anknytningens betydelse inom sm\u00e5barnspedagogiken ur l\u00e4rares synvinkel : En intervjustudie", "dc.contributor.author": ["Eklund, Susanne"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2023", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Inskolningenens och anknytningens betydelse inom sm\u00e5barnspedagogiken ur l\u00e4rares synvinkel \u2013 en intervjustudie", "dc.contributor.author": ["Eklund, Susanne"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2022", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "Vikingakvinnan som husmor: En filologisk n\u00e4rl\u00e4sning av Njals saga", "dc.contributor.author": ["Meinhart, Barbara"], "dc.publisher": ["Vasa universitet"], "dc.date.issued": "2020", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Vikingakvinnan som husmor : En filologisk n\u00e4rl\u00e5sning av Njals saga", "dc.contributor.author": ["Meinhart, Barbara"], "dc.publisher": ["Vasa universitet"], "dc.date.issued": "2020", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "Demokrati och handel : En empirisk studie \u00f6ver hur Hongkongs ned\u00e5gende demokrati p\u00e5verkar handeln med EU", "dc.contributor.author": ["Eriksson, Anna"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021-05-15", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Demokrati och handel : En empirisk studie \u00f6ver hur Hongkongs nedg\u00e4ende demokrati p\u00e5verkar handeln med EU", "dc.contributor.author": ["Eriksson, Anna"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "F\u00f6retags\u00f6vergripande riskhantering - modell och praktik", "dc.contributor.author": ["Ahonen, Noora"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "F\u00f6retags\u00f6vergripande riskhantering : modell och praktik", "dc.contributor.author": ["Ahonen, Noora"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "Vem \u00e4ger sj\u00e4lens ranka? : Ayahuascaturism utifr\u00e5n tre dokument\u00e4rer", "dc.contributor.author": ["Andersson, Tove"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Vem \u00e4ger sj\u00e4lens ranka? Ayahuascaturism utifr\u00e5n tre dokument\u00e4rer", "dc.contributor.author": ["Andersson, Tove"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "Kartl\u00e4ggning och f\u00f6rb\u00e4ttring av  processer i IT-f\u00f6retag: En modell f\u00f6r verksamhetsf\u00f6rb\u00e4ttring", "dc.contributor.author": ["Etzell, Emilia"], "dc.publisher": ["Yrkeh\u00f6gskolan Novia"], "dc.date.issued": "2020", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Kartl\u00e4ggning och f\u00f6rb\u00e4ttring av processer i IT-f\u00f6retag : En modell f\u00f6r verksamhetsf\u00f6rb\u00e4tning", "dc.contributor.author": ["Etzell, Emilia"], "dc.publisher": ["Yrkeh\u00f6gskolan Novia"], "dc.date.issued": "2020-01-10", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "H\u00e5llbara ink\u00f6p hos tv\u00e5 \u00e5l\u00e4ndska f\u00f6retag : verksamma inom plastindustrin", "dc.contributor.author": ["Eklund, Liz", "Marjanen, Emma"], "dc.publisher": ["H\u00f6gskolan p\u00e5 \u00c5land"], "dc.date.issued": "2021", "dc.language.iso": "swe", "dc.relation.eissn": "1458-1531"}
# Prediction:
# {"dc.title": "H\u00e5llbara ink\u00f6p hos två \u00e5ländska f\u00f6retag - verksamma inom plastindustrin", "dc.contributor.author": ["Eklund, Liz", "Marjanen, Emma"], "dc.publisher": ["H\u00f6gskolan p\u00e5 \u00c5land"], "dc.date.issued": "2021", "dc.language.iso": "swe", "dc.relation.eissn": "1458-1531"}
#
# Ground Truth:
# {"dc.title": "GDPR i praktiken", "dc.contributor.author": ["Kahrimanovic, Arnel", "Mesic, Selma"], "dc.publisher": ["H\u00f6gskolan p\u00e5 \u00c5land"], "dc.date.issued": "2020", "dc.language.iso": "swe", "dc.relation.eissn": "1458-1531"}
# Prediction:
# {"dc.title": "GDPR i praktiken", "dc.contributor.author": ["Kahrimanovic, Arnel", "Mesic, Selma"], "dc.publisher": ["H\u00f6gskolan p\u00e5 \u00c5land"], "dc.date.issued": "2020", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "Orderhantering f\u00f6r  automationstruckssystem med  Siemens S7-1500 Logik", "dc.contributor.author": ["Wargh, Tobias"], "dc.publisher": ["Yrkesh\u00f6gskolan Novia"], "dc.date.issued": "2021-04-20", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Orderhantering f\u00f6r automationstruckssystem med Siemens S7-1500 Logik", "dc.contributor.author": ["Wargh, Tobias"], "dc.publisher": ["Yrkesh\u00f6gskolan Novia"], "dc.date.issued": "2021", "dc.language.iso": "swe"}
#
# Ground Truth:
# {"dc.title": "EN L\u00c5NG RESA En litteratur\u00f6versikt om kvinnors erfarenheter i samband med br\u00f6strekonstruktion efter mastektomi till f\u00f6ljd av br\u00f6stcancer", "dc.contributor.author": ["Zvidrina, Arita", "Uzelac-Varda, Silvija"], "dc.publisher": ["H\u00f6gskolan p\u00e5 \u00c5land"], "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.relation.eissn": "1458-1531"}
# Prediction:
# {"dc.title": "En l\u00e4ng resa : En litteratur\u00f6versikt om kvinnors erfarenheter i samband med br\u00f6strekonstruktion efter mastektomi till f\u00f6ljd av br\u00f6stcancer", "dc.contributor.author": ["Uzelac-Varda, Silvija", "Zvidrina, Arita"], "dc.publisher": ["H\u00f6gskolan p\u00e5 \u00c5land"], "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.relation.eissn": "1458-1531"}
#
# Ground Truth:
# {"dc.title": "Fr\u00e5n \u00c5lands Sj\u00f6fartsl\u00e4roverk till H\u00f6gskolan p\u00e5 \u00c5land: En studie om intresset f\u00f6r sj\u00f6kaptensstudier \u00f6ver tid", "dc.contributor.author": ["Skoglund, Wilhelm"], "dc.publisher": ["H\u00f6gskolan p\u00e5 \u00c5land"], "dc.date.issued": "2021", "dc.language.iso": "swe", "dc.relation.eissn": "1458-1531"}
# Prediction:
# {"dc.title": "Fr\u00e5n \u00c5lands sj\u00f6fartsl\u00e4roverk till \u00c5lgskolan p\u00e5 \u00c5land - En studie om intresset f\u00f6r sj\u00f6kaptensstudier \u00f6ver tid", "dc.contributor.author": ["Skoglund, Wilhelm"], "dc.publisher": ["H\u00f6gskolan p\u00e5 \u00c5land"], "dc.date.issued": "2021", "dc.language.iso": "swe", "dc.relation.eissn": "1458-1531"}
#
# Ground Truth:
# {"dc.title": "Essays on economic productivity", "dc.contributor.author": ["L\u00e4hdem\u00e4ki, Sakari"], "dc.date.issued": "2021-03-05", "dc.identifier.isbn": ["978-951-29-8349-0"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku, Turku School of Economics"], "dc.relation.eissn": "2343-3167"}
# Prediction:
# {"dc.title": "Essays on Economic Productivity", "dc.contributor.author": ["L\u00e4hdem\u00e4ki, Sakari"], "dc.date.issued": "2021-03-26", "dc.identifier.isbn": ["978-951-29-8349-0"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku"], "dc.relation.eissn": "2343-3167"}
#
# Ground Truth:
# {"dc.title": "Educating global citizens : a study of interaction between NGOs and schools in Finland", "dc.contributor.author": ["Henriksson, Heidi"], "dc.date.issued": "2022-10-07", "dc.identifier.isbn": ["978-952-389-029-9"], "dc.language.iso": "eng", "dc.publisher": ["\u00c5bo Akademis f\u00f6rlag - \u00c5bo Akademi University Press"]}
# Prediction:
# {"dc.title": "Educating global citizens : a study of interaction between NGOs and schools in Finland", "dc.contributor.author": ["Henriksson, Heidi"], "dc.date.issued": "2022-10-07", "dc.identifier.isbn": ["978-952-389-029-9"], "dc.language.iso": "eng", "dc.publisher": ["\u00c5bo Akademis f\u00f6rlag - \u00c5bo Akademi University Press"]}
#
# Ground Truth:
# {"dc.title": "Surgical, Oncological and Reconstructive Outcomes After Complex Oncological Pelvic Resections : The Development of an Algorithm Based on a Multidisciplinary Approach", "dc.contributor.author": ["Kiiski, Juha"], "dc.date.issued": "2020", "dc.identifier.isbn": ["978-952-03-1654-9"], "dc.language.iso": "eng", "dc.publisher": ["Tampere University"], "dc.relation.eissn": "2490-0028"}
# Prediction:
# {"dc.title": "Surgical, Oncological and Reconstructive Outcomes After Complex Oncological Pelvic Resections : The Development of an Algorithm Based on a Multidisciplinary Approach", "dc.contributor.author": ["Kiiski, Juha"], "dc.date.issued": "2020-08-21", "dc.identifier.isbn": ["978-952-03-1654-9"], "dc.language.iso": "eng", "dc.publisher": ["Tampere University"], "dc.relation.eissn": "2490-0028"}
#
# Ground Truth:
# {"dc.title": "Performance Exploration and Testing of Web-based Software Systems", "dc.contributor.author": ["Ahmad, Tanwir"], "dc.date.issued": "2020-12-07", "dc.identifier.isbn": ["978-952-12-3999-1"], "dc.language.iso": "eng", "dc.publisher": ["\u00c5bo Akademi University"]}
# Prediction:
# {"dc.title": "Performance Exploration and Testing of Web-based Software Systems", "dc.contributor.author": ["Ahmad, Tanwir"], "dc.date.issued": "2020-11-20", "dc.identifier.isbn": ["978-952-12-4000-3"], "dc.language.iso": "eng", "dc.publisher": ["\u00c5bo Akademi - \u00c5bo Akademi University"]}
#
# Ground Truth:
# {"dc.title": "A Jungian Theory of Mind : Individuality, lost, gained, and transcended", "dc.contributor.author": ["Alho, P\u00e4ivi"], "dc.date.issued": "2020-05-08", "dc.identifier.isbn": ["978-952-12-3908-3"], "dc.language.iso": "eng", "dc.publisher": ["\u00c5bo Akademi University"]}
# Prediction:
# {"dc.title": "A Jungian Theory of Mind : Individuality lost, gained, and transcended", "dc.contributor.author": ["Alho, P\u00e4ivi"], "dc.date.issued": "2020", "dc.identifier.isbn": ["978-952-12-3908-3"], "dc.language.iso": "eng", "dc.publisher": ["\u00c5bo Akademi University"]}
#
# Ground Truth:
# {"dc.title": "Changes in mental health symptoms, bullying involvement, loneliness and service use among Finnish-speaking children aged 8-9 years over a 24-year period : A population-based study", "dc.contributor.author": ["Lempinen, Lotta"], "dc.date.issued": "2021-12-03", "dc.identifier.isbn": ["978-951-29-8676-7"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku"], "dc.relation.eissn": "2343-3213"}
# Prediction:
# {"dc.title": "Changes in mental health symptoms, bullying involvement, loneliness and service use among Finnish-speaking children aged 8-9 years over a 24-year period : A population-based study", "dc.contributor.author": ["Lempinen, Lotta"], "dc.date.issued": "2021-11-26", "dc.identifier.isbn": ["978-951-29-8676-7"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku"], "dc.relation.eissn": "2343-3213"}
#
# Ground Truth:
# {"dc.title": "Light Field Compression Using Disparity-Based 4D Predictive Coding", "dc.contributor.author": ["Astola, Pekka"], "dc.date.issued": "2020", "dc.identifier.isbn": ["978-952-03-1582-5"], "dc.language.iso": "eng", "dc.publisher": ["Tampere University"], "dc.relation.eissn": "2490-0028"}
# Prediction:
# {"dc.title": "Light Field Compression Using Disparity-Based 4D Predictive Coding", "dc.contributor.author": ["Astola, Pekka"], "dc.date.issued": "2020-06-05", "dc.identifier.isbn": ["978-952-03-1582-5"], "dc.language.iso": "eng", "dc.publisher": ["Tampere University"], "dc.relation.eissn": "2490-0028"}
#
# Ground Truth:
# {"dc.title": "Aminophenolato complexes of Mo, W and V In catalytic alkene epoxidation and catechol oxidation", "dc.contributor.author": ["Salonen, Pasi"], "dc.date.issued": "2021-11-05", "dc.identifier.isbn": ["978-951-29-8655-2"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku"], "dc.relation.eissn": "2343-3175"}
# Prediction:
# {"dc.title": "Aminophenolato Complexes of Mo, W, and V in Catalytic Alkene Epoxidation and Catechol Oxidation", "dc.contributor.author": ["Salonen, Pasi"], "dc.date.issued": "2021-10-22", "dc.identifier.isbn": ["978-951-29-8655-2"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku"], "dc.relation.eissn": "2343-3175"}
#
# Ground Truth:
# {"dc.title": "Employee trust repair in the context of organizational change \u2013 identification and measurement of active trust repair practices", "dc.contributor.author": ["K\u00e4hk\u00f6nen, Tiina"], "dc.date.issued": "2022-01-21", "dc.identifier.isbn": ["978-952-335-776-1"], "dc.language.iso": "eng", "dc.publisher": ["Lappeenranta-Lahti University of Technology LUT"]}
# Prediction:
# {"dc.title": "Employee trust repair in the context of organizational change : identification and measurement of active trust repair practices", "dc.contributor.author": ["K\u00e4hk\u00f6nen, Tiina"], "dc.date.issued": "2022-01-21", "dc.identifier.isbn": ["978-952-335-776-1"], "dc.language.iso": "eng", "dc.publisher": ["Lappeenranta-Lahti University of Technology LUT"]}
#
# Ground Truth:
# {"dc.title": "Problem gambling in a Nordic context : Moving from social factors to a psychosocial perspective", "dc.contributor.author": ["Nordmyr, Johanna"], "dc.date.issued": "2020-10-02", "dc.identifier.isbn": ["978-952-12-3870-0"], "dc.language.iso": "eng", "dc.publisher": ["\u00c5bo Akademi University"]}
# Prediction:
# {"dc.title": "Problem gambling in a Nordic context : Moving from social factors to a psychosocial perspective", "dc.contributor.author": ["Nordmyr, Johanna"], "dc.date.issued": "2020-10-02", "dc.identifier.isbn": ["978-952-12-3870-0"], "dc.language.iso": "eng", "dc.publisher": ["\u00c5bo Akademi - \u00c5bo Akademi University"]}
#
# Ground Truth:
# {"dc.title": "Light Manipulation in Multilayer Metamaterials", "dc.contributor.author": ["Habib, Mohsin"], "dc.date.issued": "2022-06-20", "dc.identifier.isbn": ["978-952-03-2451-3"], "dc.language.iso": "eng", "dc.publisher": ["Tampere University"], "dc.relation.eissn": "2490-0028"}
# Prediction:
# {"dc.title": "Light Manipulation in Multilayer Metamaterials", "dc.contributor.author": ["Habib, Mohsin"], "dc.date.issued": "2022-06-03", "dc.identifier.isbn": ["978-952-03-2451-3"], "dc.language.iso": "eng", "dc.publisher": ["Tampere University"], "dc.relation.eissn": "2490-0028"}
#
# Ground Truth:
# {"dc.title": "Causes and consequences of variation in blue tit nest construction", "dc.contributor.author": ["J\u00e4rvinen, Pauliina"], "dc.date.issued": "2020-05-08", "dc.identifier.isbn": ["978-951-29-8067-3"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku"], "dc.relation.eissn": "2343-3183"}
# Prediction:
# {"dc.title": "Causes and consequences of variation in blue tit nest construction", "dc.contributor.author": ["J\u00e4rvinen, Pauliina"], "dc.date.issued": "2020-04-24", "dc.identifier.isbn": ["978-951-29-8067-3"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku"], "dc.relation.eissn": "2343-3183"}
#
# Ground Truth:
# {"dc.title": "Role of Urinary Findings and Adipokines in Puumala Virus-induced Acute Kidney Injury", "dc.contributor.author": ["Mantula, Paula"], "dc.date.issued": "2021-04-16", "dc.identifier.isbn": ["978-952-03-1880-2"], "dc.language.iso": "eng", "dc.publisher": ["Tampere University"], "dc.relation.eissn": "2490-0028"}
# Prediction:
# {"dc.title": "Role of Urinary Findings and Adipokines in Puumala Virus-induced Acute Kidney Injury", "dc.contributor.author": ["Mantula, Paula"], "dc.date.issued": "2021-03-12", "dc.identifier.isbn": ["978-952-03-1880-2"], "dc.language.iso": "eng", "dc.publisher": ["Tampere University"], "dc.relation.eissn": "2490-0028"}
#
# Ground Truth:
# {"dc.title": "Rescheduling sudden absences of nursing staff in hospital settings", "dc.contributor.author": ["Tuominen, Outi"], "dc.date.issued": "2020-02-21", "dc.identifier.isbn": ["978-951-29-7961-5"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku"], "dc.relation.eissn": "2343-3213"}
# Prediction:
# {"dc.title": "Rescheduling sudden absences of nursing staff in hospital settings", "dc.contributor.author": ["Tuominen, Outi"], "dc.date.issued": "2020-02-28", "dc.identifier.isbn": ["978-951-29-7961-5"], "dc.language.iso": "eng", "dc.publisher": ["University of Turku"], "dc.relation.eissn": "2343-3213"}
#
# Ground Truth:
# {"dc.title": "Power of Myths in Energy Transition : Unveiling Timeless Mythologies in Finnish Energy Agora", "dc.contributor.author": ["Berg, Petra"], "dc.date.issued": "2021-04-13", "dc.identifier.isbn": ["978-952-476-949-5"], "dc.language.iso": "eng", "dc.publisher": ["Vaasan yliopisto"], "dc.relation.eissn": "2323-9123"}
# Prediction:
# {"dc.title": "Power of Myths in Energy Transition: Unveiling Timeless Mythologies in Finnish Energy Agora", "dc.contributor.author": ["Berg, Petra"], "dc.date.issued": "2021-04-23", "dc.identifier.isbn": ["978-952-476-949-5"], "dc.language.iso": "eng", "dc.publisher": ["Vaasan yliopisto"], "dc.relation.eissn": "2323-9123"}
#
# Ground Truth:
# {"dc.title": "A Dynamic Collusion Analysis Framework Considering Generation and Transmission Systems Maintenance Constraints", "dc.contributor.author": ["Tabatabaei, Mostafa", "Setayesh Nazar, Mehrdad", "Shafie-khah, Miadreza", "Catal\u00e3o, Jo\u00e3o P. S."], "dc.date.issued": "2020-10-13", "dc.identifier.isbn": ["978-1-7281-6919-4"], "dc.language.iso": "eng", "dc.publisher": ["IEEE"]}
# Prediction:
# {"dc.title": "A Dynamic Collusion Analysis Framework Considering Generation and Transmission Systems Maintenance Constraints", "dc.contributor.author": ["Tabatabaei, Mostafa", "Setayesh Nazar, Mehrdad", "Shafie-khah, Miadreza", "Catal\u00e3o, Jo\u00e3o P. S."], "dc.date.issued": "2020", "dc.language.iso": "eng", "dc.publisher": ["IEEE"]}
#
# Ground Truth:
# {"dc.title": "Finnish Journal for Romanian Studies 4", "dc.contributor.author": ["Jarvis, Bob", "Diaconu, M\u0103d\u0103lina", "Ciol\u0103neanu, Roxana", "Rotaru, Marina-Cristiana", "Constantinescu, C\u0103t\u0103lin"], "dc.date.issued": "2018", "dc.relation.eissn": "2343-3450", "dc.language.iso": "eng", "dc.publisher": ["University of Turku"]}
# Prediction:
# {"dc.title": "The symbolism of the mountain in the modern Romanian culture", "dc.contributor.author": ["Diaconescu, Madalina"], "dc.date.issued": "2018", "dc.language.iso": "eng", "dc.publisher": ["University of Turku"]}
#
# Ground Truth:
# {"dc.title": "Channels of dialogue between international businesses and national governments : The implications for domestic reforms and international relations in the case of Russia", "dc.contributor.author": ["Yakovlev, Andrei", "Freinkman, Lev", "Ershova, Nina"], "dc.date.issued": "2018-06-15", "dc.relation.eissn": "2342-205X", "dc.language.iso": "eng", "dc.publisher": ["Bank of Finland"]}
# Prediction:
# {"dc.title": "Channels of dialogue between international businesses and national governments: The implications for domestic reforms and international relations in the case of Russia", "dc.contributor.author": ["Yakovlev, Andrei", "Freinkman, Lev", "Ershova, Nina"], "dc.date.issued": "2018-06-15", "dc.language.iso": "eng", "dc.publisher": ["Bank of Finland"]}
#
# Ground Truth:
# {"dc.title": "Culturally and linguistically diverse healthcare students\u2019 experiences of the clinical learning environment and mentoring : a qualitative study", "dc.contributor.author": ["Korhonen, Heidi", "Tuomikoski, Anna-Maria", "Oikarainen, Ashlee", "K\u00e4\u00e4ri\u00e4inen, Maria", "Elo, Satu", "Kyng\u00e4s, Helvi", "Liikanen, Eeva", "Mikkonen, Kristina"], "dc.date.issued": "2019", "dc.language.iso": "eng", "dc.publisher": ["Elsevier"]}
# Prediction:
# {"dc.title": "Culturally and linguistically diverse healthcare students\u2019 experiences of the clinical learning environment and mentoring : a qualitative study", "dc.contributor.author": ["Korhonen, Hanna", "Tuomikoski, Anna-Maarit", "Oikarainen, Anna", "K\u00e4\u00e4ri\u00e4inen, Mari", "Elo, Sanna", "Kyng\u00e4s, Heidi", "Liikanen, Eija", "Mikkonen, Kaisa"], "dc.date.issued": "2019", "dc.language.iso": "eng", "dc.publisher": ["Elsevier"]}
#
# Ground Truth:
# {"dc.title": "A review of optical nondestructive visual and near-infrared methods for food quality and safety", "dc.contributor.author": ["Alander, Jarmo T.", "Bochko, Vladimir", "Martinkauppi, Birgitta", "Saranwong, Sirinnapa", "Mantere, Timo"], "dc.date.issued": "2013-03-24", "dc.language.iso": "eng", "dc.publisher": ["Hindawi"]}
# Prediction:
# {"dc.title": "A Review of Optical Nondestructive Visual and Near-Infrared Methods for Food Quality and Safety", "dc.contributor.author": ["Alander, Jarmo T.", "Bochko, Vladimir", "Martinkauppi, Birgitta", "Saranwong, Sirinnapa"], "dc.date.issued": "2013", "dc.language.iso": "eng", "dc.publisher": ["Hindawi Publishing Corporation"]}
#
# Ground Truth:
# {"dc.title": "Engaging audio based mobile applications", "dc.contributor.author": ["Salo, Kari", "Neuvonen, Aura"], "dc.date.issued": "2019", "dc.identifier.isbn": ["9788409147557"], "dc.language.iso": "eng", "dc.publisher": ["IATED"]}
# Prediction:
# {"dc.title": "Engaging audio based mobile applications", "dc.contributor.author": ["Salo, Kari", "Neuvonen, Aura"], "dc.date.issued": "2019", "dc.identifier.isbn": ["978-84-09-14755-7"], "dc.language.iso": "eng", "dc.publisher": ["Universitat Politecnica de Catalunya"]}
#
# Ground Truth:
# {"dc.title": "Finland in Figures 2015", "dc.date.issued": "2015", "dc.relation.eissn": "2242-8496", "dc.identifier.isbn": ["978-952-244-589-6"], "dc.language.iso": "eng", "dc.publisher": ["Statistics Finland"]}
# Prediction:
# {"dc.title": "Finland in Figures 2015", "dc.date.issued": "2015", "dc.relation.eissn": "2242-8262", "dc.identifier.isbn": ["978-952-244-971-6"], "dc.language.iso": "eng", "dc.publisher": ["Statistics Finland"]}
#
# Ground Truth:
# {"dc.title": "Bothnian Bay Hydrogen Valley \u2013  Research report", "dc.contributor.author": ["Karjunen, Hannu", "Lassila, Jukka", "Tynj\u00e4l\u00e4, Tero", "Laaksonen, Petteri", "Tuomaala, Mari", "Vilppo, Julius", "Taulasto, Kimmo", "Karppanen, Janne", "Laari, Arto", "Kosonen, Antti", "Ahola, Jero"], "dc.date.issued": "2021-10-31", "dc.identifier.isbn": ["978-952-335-763-1"], "dc.language.iso": "eng", "dc.publisher": ["LUT University"]}
# Prediction:
# {"dc.title": "Bothnian Bay Hydrogen Valley : Research report", "dc.contributor.author": ["Karjunen, Hannu", "Lassila, Jukka", "Tynj\u00e4l\u00e4, Tero", "Laaksonen, Petteri", "Tuomaala, Mari", "Vilppo, Julius", "Taulasto, Kimmo", "Karppanen, Janne", "Laari, Arto", "Kosonen, Antti", "Ahola, Jero"], "dc.date.issued": "2021", "dc.identifier.isbn": ["978-952-335-763-1"], "dc.language.iso": "eng", "dc.publisher": ["Lappeenranta-Lahti University of Technology LUT"]}
#
# Ground Truth:
# {"dc.title": "Housing market and current account imbalances in the international economy", "dc.contributor.author": ["Punzi, Maria Teresa"], "dc.date.issued": "2012-01-09", "dc.relation.eissn": "1456-6184", "dc.identifier.isbn": ["978-952-462-784-9"], "dc.language.iso": "eng", "dc.publisher": ["Bank of Finland"]}
# Prediction:
# {"dc.title": "Housing market and current account imbalances in the international economy", "dc.contributor.author": ["Punzi, Maria Teresa"], "dc.date.issued": "2012", "dc.relation.eissn": "1456-6184", "dc.identifier.isbn": ["978-952-462-784-9"], "dc.language.iso": "eng", "dc.publisher": ["Bank of Finland"]}
#
# Ground Truth:
# {"dc.title": "How to explain errors in budget balance forecasts in euro area countries? Empirical evidence based on real-time data", "dc.contributor.author": ["Paloviita, Maritta", "Ikonen, Pasi"], "dc.date.issued": "2016-06-17", "dc.relation.eissn": "1456-6184", "dc.identifier.isbn": ["978-952-323-114-6"], "dc.language.iso": "eng", "dc.publisher": ["Bank of Finland"]}
# Prediction:
# {"dc.title": "How to explain errors in budget balance forecasts in euro area countries? Real-time evidence based on IMF data", "dc.contributor.author": ["Paloviita, Maritta", "Ikonen, Pasi"], "dc.date.issued": "2016-06-24", "dc.relation.eissn": "1456-6184", "dc.identifier.isbn": ["978-952-323-114-6"], "dc.language.iso": "eng", "dc.publisher": ["Bank of Finland"]}
#
# Ground Truth:
# {"dc.title": "Supporting Transformative Agency among Urban Actors in the Change Laboratory Intervention", "dc.contributor.author": ["Lund, Virpi"], "dc.date.issued": "2021", "dc.relation.eissn": "2328-4919", "dc.language.iso": "eng", "dc.publisher": ["Scientific Research Publishing"]}
# Prediction:
# {"dc.title": "Supporting Transformative Agency among Urban Actors in the Change Laboratory Intervention", "dc.contributor.author": ["Lund, Virpi"], "dc.date.issued": "2021", "dc.language.iso": "eng", "dc.publisher": ["Scientific Research Publishing"]}
#
# Ground Truth:
# {"dc.title": "In the shadows : Phenomenological choreographic writing", "dc.contributor.author": ["Heimonen, Kirsi", "Rouhiainen, Leena"], "dc.date.issued": "2022", "dc.language.iso": "eng", "dc.publisher": ["Intellect"]}
# Prediction:
# {"dc.title": "In the Shadows: Phenomenological Choreographic Writing", "dc.contributor.author": ["Heimonen, Kirsi", "Rouhiainen, Leena"], "dc.date.issued": "2022", "dc.language.iso": "eng", "dc.publisher": ["Taylor & Francis"]}
#
# Ground Truth:
# {"dc.title": "Epistemically tuned-in?", "dc.contributor.author": ["St\u00e5hl, Tore"], "dc.date.issued": "2020", "dc.language.iso": "eng", "dc.publisher": ["European Association for Practitioner Research"]}
# Prediction:
# {"dc.title": "Epistemically Tuned-in?", "dc.contributor.author": ["St\u00e5hl, Tore"], "dc.date.issued": "2020", "dc.language.iso": "eng", "dc.publisher": ["EAPRIL"]}
#
# Ground Truth:
# {"dc.title": "Memories from the EAHIL Workshop", "dc.contributor.author": ["Hagstr\u00f6m, Sarah", "Larmo, Katri", "Mann, Mala", "Ferrinho, Ana Maria", "Ottjes, Robin"], "dc.date.issued": "2019", "dc.language.iso": "eng", "dc.publisher": ["EAHIL"]}
# Prediction:
# {"dc.title": "Memories from the EAHIL Workshop \u201cLearn, Share, Act, Bridge Borders\u201d", "dc.contributor.author": ["Hagstr\u00f6m, Sarah", "Larmo, Katri", "Mann, Mala", "Ferrinho, Ana Maria", "Ottjes, Robin"], "dc.date.issued": "2019", "dc.language.iso": "eng", "dc.publisher": ["European Association of Health Information and Libraries"]}
#
# Ground Truth:
# ...
#
# Ground Truth:
# {"dc.title": "Resource Productivity as the EU\u00b4s Lead Resource Efficiency Indicator : a quantitative macro-comparative study on indicator drivers", "dc.contributor.author": ["J\u00e4rnefelt, Elisabeth"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021-05-12", "dc.language.iso": "eng"}
# Prediction:
# {"dc.title": "Resource Productivity as the EU\u2019s Lead Resource Efficiency Indicator : a quantitative macro-comparative study on indicator drivers", "dc.contributor.author": ["J\u00e4rnefelt, Elisabeth"], "dc.publisher": ["\u00c5bo Akademi"], "dc.date.issued": "2021", "dc.language.iso": "eng"}
#
# Ground Truth:
# {"dc.title": "Developing a football game for Android", "dc.contributor.author": ["Huhtam\u00e4ki, Markus"], "dc.publisher": ["Tampere University of Applied Sciences"], "dc.date.issued": "2021-03", "dc.language.iso": "eng"}
# Prediction:
# {"dc.title": "Developing a Football Game for Android", "dc.contributor.author": ["Huhtam\u00e4ki, Markus"], "dc.publisher": ["Tampere University of Applied Sciences"], "dc.date.issued": "2021-03", "dc.language.iso": "eng"}
#
# Ground Truth:
# {"dc.title": "Creating and implementing a business process model", "dc.contributor.author": ["Skog, Patrik"], "dc.publisher": ["Yrkeh\u00f6gskolan Novia"], "dc.date.issued": "2020", "dc.language.iso": "eng"}
# Prediction:
# {"dc.title": "Creating and implementing a business process model", "dc.contributor.author": ["Skog, Patrik"], "dc.publisher": ["Taideyliopiston ammattikorkeakoulu"], "dc.date.issued": "2020-02-17", "dc.language.iso": "eng"}
#
# Ground Truth:
# {"dc.title": "An analysis of Facebook posts", "dc.contributor.author": ["To, My"], "dc.publisher": ["Yrkeh\u00f6gskolan Arcada"], "dc.date.issued": "2020", "dc.language.iso": "eng"}
# Prediction:
# {"dc.title": "An analysis of Facebook posts", "dc.contributor.author": ["My, Nguyen Ngoc"], "dc.publisher": ["Yrkeh\u00f6gskolan Arcada"], "dc.date.issued": "2020", "dc.language.iso": "eng"}
#
# Ground Truth:
# {"dc.title": "The cultural history of politics in Swedish contemporary art.", "dc.contributor.author": ["Kozma, Madeleine"], "dc.publisher": ["Yrkeh\u00f6gskolan Novia"], "dc.date.issued": "2020", "dc.language.iso": "eng"}
# Prediction:
# {"dc.title": "The cultural history of politics in Swedish contemporary art", "dc.contributor.author": ["Kozma, Madeleine"], "dc.publisher": ["Novia University of Applied Sciences"], "dc.date.issued": "2020-11-11", "dc.language.iso": "eng"}
#
# Ground Truth:
# {"dc.title": "N\u00e4r man g\u00e5r i stora skor l\u00e4mnar man stora sp\u00e5r efter sig : aderton perspektiv p\u00e5 polisarbetet : studiematerial f\u00f6r Polisyrkesh\u00f6gskolans intr\u00e4desprov 2014", "dc.date.issued": "2014", "dc.identifier.isbn": ["978-951-815-263-0"], "dc.language.iso": "swe", "dc.publisher": ["Polisyrkesh\u00f6gskolan"]}
# Prediction:
# {"dc.title": "N\u00e4r man g\u00e5r i stora skor l\u00e4mnar man stora sp\u00e5r efter sig : Aderton perspektiv p\u00e5 polisarbetet", "dc.contributor.author": ["Asmundela, Saara", "Haikansalo, Anu", "Heinam\u00e4ki, Anna-Kaisa", "Helenius, Jutta", "Hiilamo, Heikki", "Jokiniemi, Maritta", "Katajam\u00e4ki, Elina", "Kelloniemi, Henna", "Konstig, Joonas", "Laukka, Minna", "Loikkanen, Pekka", "Majanen, Jussi", "Nyman, Markku", "Pelttari, Mikko", "Perttula, Jouni", "Vesterbacka, Marko"], "dc.date.issued": "2014", "dc.language.iso": "swe", "dc.publisher": ["Polisyrkesh\u00f6gskolan"]}
#
# Ground Truth:
# {"dc.title": "Norra \u00d6sterbotten och oj\u00e4mlikhet : infograf \u00e5t v\u00e4lf\u00e4rdsomr\u00e5desfullm\u00e4ktige", "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.publisher": ["Institutet f\u00f6r h\u00e4lsa och v\u00e4lf\u00e4rd THL = Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "Norra \u00d6sterbotten och oj\u00e4mlikhet : Ledamot i v\u00e4lf\u00e4rds\u00f6m\u00e4rkesfullm\u00e4ktige", "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.publisher": ["Infograaf"]}
#
# Ground Truth:
# {"dc.title": "Egentliga Finland och oj\u00e4mlikhet : infograf \u00e5t v\u00e4lf\u00e4rdsomr\u00e5desfullm\u00e4ktige", "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.publisher": ["Institutet f\u00f6r h\u00e4lsa och v\u00e4lf\u00e4rd THL = Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "Egentliga Finland och oj\u00e4mlikhet : Ledamot i v\u00e4lf\u00e4rds\u00f6m\u00e4rkesfullm\u00e4ktige", "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.publisher": ["Infograaf"]}
#
# Ground Truth:
# {"dc.title": "Att v\u00e5rda vattendrag tillsammans : Kommunikation och anpassning till klimatf\u00f6r\u00e4ndringens utmaningar i Herts\u00e5nger\u00e4lven och Toby \u00e5 (Laihianjoki)", "dc.contributor.author": ["Nordberg, Kenneth", "Ghorbanzadeh, Sakineh"], "dc.date.issued": "2022", "dc.identifier.isbn": ["978-952-12-4232-8"], "dc.language.iso": "swe", "dc.publisher": ["Regionalvetenskap, \u00c5bo Akademi"]}
# Prediction:
# {"dc.title": "Att v\u00f6rda vattendrag tillsammans : Kommunikation och anpassning till klimatf\u00f6r\u00e4ndringens utmaningar i Herts\u00e5nger\u00e4lven och Toby \u00e5 (Laihianjoki)", "dc.contributor.author": ["Nordberg, Kenneth", "Ghorbanzadeh, Sakineh"], "dc.date.issued": "2022-10-21", "dc.identifier.isbn": ["978-952-12-4232-8"], "dc.language.iso": "swe", "dc.publisher": ["\u00c5bo Akademi"]}
#
# Ground Truth:
# {"dc.title": "D\u00e4r kunskapen t\u00e4tnar som moln : Ess\u00e4er om litteraturen som kunskapsf\u00e4lt och kunskapsform", "dc.date.issued": "2021", "dc.identifier.isbn": ["978-952-12-4020-1"], "dc.language.iso": "swe", "dc.publisher": ["Litteraturvetenskap och filosofi vid \u00c5bo Akademi"]}
# Prediction:
# {"dc.title": "D\u00e4r kunskapen t\u00e4tnar som moln : ess\u00e4er om litteraturen som kunskapsf\u00e5lt och kunskapsform", "dc.date.issued": "2021", "dc.identifier.isbn": ["978-952-12-4020-1"], "dc.language.iso": "swe", "dc.publisher": ["Litteraturvetenskap och filosofi vid \u00c5bo Akademi"]}
#
# Ground Truth:
# {"dc.title": "Norra Karelen och oj\u00e4mlikhet : infograf \u00e5t v\u00e4lf\u00e4rdsomr\u00e5desfullm\u00e4ktige", "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.publisher": ["Institutet f\u00f6r h\u00e4lsa och v\u00e4lf\u00e4rd THL = Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "Norra Karelen och oj\u00e4mlikhet : Ledamot i v\u00e4lf\u00e4rds\u00f6m\u00e4rkesfullm\u00e4ktige", "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.publisher": ["Infograaf"]}
#
# Ground Truth:
# {"dc.title": "P\u00e4ij\u00e4nne-Tavastland och oj\u00e4mlikhet : infograf \u00e5t v\u00e4lf\u00e4rdsomr\u00e5desfullm\u00e4ktige", "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.publisher": ["Institutet f\u00f6r h\u00e4lsa och v\u00e4lf\u00e4rd THL = Terveyden ja hyvinvoinnin laitos"]}
# Prediction:
# {"dc.title": "P\u00e4ij\u00e4nne-Tavastland och oj\u00e4mlikhet : Ledamot i v\u00e4lf\u00e4rds\u00f6m\u00e4rkesfullm\u00e4ktige", "dc.date.issued": "2022", "dc.language.iso": "swe", "dc.publisher": ["Infograaf"]}
#
# Ground Truth:
# {"dc.title": "Svenskfinland i pandemitider : Resultat fr\u00e5n den finlandssvenska medborgarpanelen Barometern 2020\u20132022", "dc.contributor.author": ["Backstr\u00f6m, Jenny", "Backstr\u00f6m, Kim", "Karv, Thomas", "Lindell, Marina", "Malmberg, Fredrik", "Schauman, Jonas", "Sir\u00e9n, Rasmus", "Weckman, Albert"], "dc.date.issued": "2022", "dc.identifier.isbn": ["978-952-12-4210-6"], "dc.language.iso": "swe", "dc.publisher": ["Institutet f\u00f6r samh\u00e4llsforskning (Samforsk), \u00c5bo Akademi, Vasa"]}
# Prediction:
# {"dc.title": "Svenskfinland i pandemitider : Resultat fr\u00e5n den finlandssvenska medborgarpanelen Barometern 2020-2022", "dc.date.issued": "2022", "dc.identifier.isbn": ["978-952-12-4210-6"], "dc.language.iso": "swe", "dc.publisher": ["Institutet f\u00f6r samh\u00e4llsforskning (Samforsk), \u00c5bo Akademi"]}
#
# Ground Truth:
# {"dc.title": "Mod och gl\u00e4dje att prata svenska online", "dc.contributor.author": ["Linna, Mari", "Mets\u00e4vainio, Marita", "Valtonen, Ida", "Kazaka, Signe", "Kihlbom, Liselotte", "Lempinen, Katja", "Suvila, Jari"], "dc.date.issued": "2020", "dc.language.iso": "swe", "dc.publisher": ["Suomen kieltenopettajien liitto"]}
# Prediction:
# {"dc.title": "Mod och gl\u00e4dje att prata svenska online", "dc.contributor.author": ["Linna, Mari", "Mets\u00e4vainio, Marita", "Valtonen, Ida", "Kazaka, Signe", "Kihlbom, Liselotte", "Lempinen, Katja", "Suvila, Jari"], "dc.date.issued": "2020", "dc.language.iso": "swe", "dc.publisher": ["Taideyliopiston yliopiston kirjasto"]}
#
# Ground Truth:
# {"dc.title": "Kompetens i palliativ v\u00e5rd i livets slutskede i sjuksk\u00f6tarexamen : rekommendation f\u00f6r l\u00e4roplan i palliativ v\u00e5rd och v\u00e5rd i livets slutskede", "dc.contributor.author": ["H\u00f6kk\u00e4, Minna"], "dc.date.issued": "2020", "dc.identifier.isbn": ["978-952-7219-60-7"], "dc.language.iso": "swe", "dc.publisher": ["Kajaanin Ammattikorkeakoulu Oy"]}
# Prediction:
# {"dc.title": "Kompetens i palliativ v\u00e5rd och v\u00e5rd i livets slutskede i sjuksk\u00f6tarexamen : Rekommendation f\u00f6r l\u00e4roplan i palliativ v\u00e5rd och v\u00e5rd i livets slutskede", "dc.contributor.author": ["H\u00f6kk\u00e4, Minna", "Lehto, Juho", "Joutsia, Karoliina", "Kallio, Suvi", "Kiiski, Katri", "Kurunsaari, Merja", "Lif\u00f6nder, Birgit", "L\u00e4hdentniemi, Marika", "Mikkonen, Heli", "Muurinen, Katja", "P\u00e4\u00e4llysaho, Annikki", "Pyk\u00e4l\u00e4inen, Tarja", "Sunikka, Tuulia", "Tohmola, Anniina", "Turunen, Irja", "V\u00e4is\u00e4nen, Irja", "Ylinen, Eeva-Riitta", "Bergman, Leila", "Kullas-Nyman, Lisen", "Sand\u00e9n-Eriksson, Lena"], "dc.date.issued": "2020", "dc.identifier.isbn": ["978-952-7219-60-7"], "dc.language.iso": "swe", "dc.publisher": ["Kajaanin Ammattikorkeakoulu"]}
#
# Ground Truth:
# {"dc.title": "Finland i siffror 2014", "dc.date.issued": "2014", "dc.relation.eissn": "2242-8488", "dc.identifier.isbn": ["978-952-244-494-3"], "dc.language.iso": "swe", "dc.publisher": ["Statistikcentralen"]}
# Prediction:
# {"dc.title": "Finland i siffror 2014", "dc.date.issued": "2014", "dc.relation.eissn": "2242-384X", "dc.identifier.isbn": ["978-952-244-938-4"], "dc.language.iso": "swe", "dc.publisher": ["Statistikcentralen"]}
#
# Ground Truth:
# {"dc.title": "Finland i siffror 2022", "dc.date.issued": "2022", "dc.relation.eissn": "2242-8488", "dc.identifier.isbn": ["978-952-244-696-1"], "dc.language.iso": "swe", "dc.publisher": ["Statistikcentralen"]}
# Prediction:
# {"dc.title": "Finland i siffror 2022", "dc.date.issued": "2022", "dc.relation.eissn": "2242-354X", "dc.identifier.isbn": ["978-952-244-764-6"], "dc.language.iso": "swe", "dc.publisher": ["Statistikcentralen"]}
#
# Ground Truth:
# {"dc.title": "Unders\u00f6kning av l\u00f6nsamheten inom lagstadgad olycksfallsf\u00f6rs\u00e4kring 2004-2013 : analys", "dc.date.issued": "2014-09-15", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Unders\u00f6kning av l\u00f6nsamheten inom lagstadgad olycksfallsf\u00f6rs\u00e4kring 2004-2013", "dc.date.issued": "2014-11-03", "dc.language.iso": "swe", "dc.publisher": ["Fennia"]}
#
# Ground Truth:
# {"dc.title": "Finsk straffr\u00e4tt : grundkurs i straffr\u00e4ttens allm\u00e4nna l\u00e4ror", "dc.contributor.author": ["Boucht, Johan", "Fr\u00e4nde, Dan"], "dc.date.issued": "2020", "dc.relation.eissn": "1455-8270", "dc.identifier.isbn": ["978-951-815-376-7"], "dc.language.iso": "swe", "dc.publisher": ["Polisyrkesh\u00f6gskolan"]}
# Prediction:
# {"dc.title": "Finsk straffr\u00e4tt : Grundkurs i straffr\u00e4ttens allm\u00e4nna l\u00e4ror", "dc.contributor.author": ["Boucht, Johan", "Fr\u00e4nde, Dan"], "dc.date.issued": "2020", "dc.identifier.isbn": ["978-951-815-376-7"], "dc.language.iso": "fin", "dc.publisher": ["Polisyrkesh\u00f6gskolan"]}
#
# Ground Truth:
# {"dc.title": "Finland i siffror 2020", "dc.date.issued": "2020", "dc.relation.eissn": "2242-8488", "dc.identifier.isbn": ["978-952-244-653-4"], "dc.language.iso": "swe", "dc.publisher": ["Statistikcentralen"]}
# Prediction:
# kmängden 19 989 4,0 25 636 4,8 32 758 5,9
# Tusen personer 120 100
# Levande födda och döda 1950 1960 1970 1980 1990 2000 2010 2019
# Levande födda 11 144 11,4 12 174 11,6 68 1 112 8,9
# Döda 11 124 10,3 12 168 11,1 72 1 112 9,2
# Naturlig folkökning 0,2 1960 0,2 1970 0,1 1980 0,0 1990 0,0 2000 0,0 2010 0,0 2019 0,0
# Inflyttning 1,0 1960 1,1 1970 1,0 1980 0,9 1990 0,8 2000 0,7 2010 0,6 2019 0,6
#  {"dc.title": "Finland i siffror 2020", "dc.date.issued": "2020", "dc.relation.eissn": "2242-545X", "dc.identifier.isbn": ["978-952-244-974-4"], "dc.language.iso": "swe", "dc.publisher": ["Statistikcentralen"]}
#
# Ground Truth:
# {"dc.title": "L\u00e5t havet forts\u00e4tta vara v\u00e4gen", "dc.contributor.author": ["Karlsson, Rasmus"], "dc.date.issued": "2019", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "L\u00e4t havet forts\u00e4tta vara v\u00e4gen", "dc.contributor.author": ["Karlsson, Rasmus"], "dc.date.issued": "2019", "dc.language.iso": "swe", "dc.publisher": ["Vasabladet"]}
#
# Ground Truth:
# {"dc.title": "Direktionens ber\u00e4ttelse till bankfullm\u00e4ktige 2012", "dc.date.issued": "2013-05-15", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Direktionens ber\u00e4ttelse till bankfullm\u00e4ktige om Finansinspektionens verksamhet 2012", "dc.date.issued": "2013", "dc.language.iso": "swe", "dc.publisher": ["Finansinspektionen"]}
#
# Ground Truth:
# {"dc.title": "Torka eller ensilera? Novia j\u00e4mf\u00f6r lagringsmetoder och utvecklar handelsmodell f\u00f6r spannm\u00e5l", "dc.contributor.author": ["Dahlb\u00e4ck, Yvonne", "Fr\u00e4nde, Niklas"], "dc.date.issued": "2019", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Torka eller ensilera? Novia j\u00e4mför lagringsmetoder och utvecklar handelsmodell f\u00f6r spannm\u00e5l", "dc.contributor.author": ["Dahlb\u00e4ck, Yvonne", "Fr\u00e4nde, Niklas"], "dc.date.issued": "2019", "dc.language.iso": "swe", "dc.publisher": ["Novia"]}
#
# Ground Truth:
# {"dc.title": "Tidskriften Sk\u00e4rg\u00e5rd 4/2017", "dc.contributor.author": ["S\u00f6derlund, Nina (red.)", "Wallin, Stefan", "Jern, Olav", "Eklund, H\u00e5kan", "Lundberg, Cecilia", "Prost, Pia", "Miiros-Hollsten, Ester", "Wrede, John", "Jansson, Micaela", "Winther, Dorthe", "Nikander, Ralf", "Mattsson, Kristin"], "dc.date.issued": "2017-12", "dc.language.iso": "swe", "dc.publisher": ["Sk\u00e4rg\u00e5rdsinstitutet vid \u00c5bo Akademi"]}
# Prediction:
# {"dc.title": "Sk\u00e4rg\u00e5rd 40 \u00e5r", "dc.date.issued": "2017", "dc.language.iso": "swe", "dc.publisher": ["Sk\u00e4rg\u00e5rd-stiftelsen"]}
#
# Ground Truth:
# {"dc.title": "Verksamhetsber\u00e4ttelse 2018", "dc.contributor.author": ["Milka Lahnalammi-Vesivalo (ordf.)", "Sampo Alhonsuo", "Miia Armila-Paalasmaa", "Raakel Heikkinen", "Hanna Heiskanen", "Anne-Mari Juutinen", "Teija Korpiaho", "Jaana Rantama", "Erja Rautanen", "Tommi Tulonen", "Kristiina Tuomikoski"], "dc.date.issued": "2019-06-28", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Verksamhetsber\u00e4ttelse 2018", "dc.date.issued": "2019-03-07", "dc.language.iso": "swe", "dc.publisher": ["Finansinspektionen"]}
#
# Ground Truth:
# {"dc.title": "Verksamhetsber\u00e4ttelse 2012", "dc.date.issued": "2013-05-25", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "Verksamhetsber\u00e4ttelse 2012", "dc.date.issued": "2013", "dc.language.iso": "swe", "dc.publisher": ["Finansinspektionen"]}
#
# Ground Truth:
# {"dc.title": "V\u00e4xtbehovsanpassade g\u00f6dselmedel fr\u00e5n biogasanl\u00e4ggningar", "dc.contributor.author": ["Nina \u00c5kerback, Viveka \u00d6ling-W\u00e4rn\u00e5 & Sten Engblom"], "dc.date.issued": "2019", "dc.language.iso": "swe"}
# Prediction:
# {"dc.title": "V\u00e4xtbehovsanpassade g\u00f6dselmedel fr\u00e5n biogasanl\u00e4ggningar", "dc.contributor.author": ["\u00c5kerback, Nina", "\u00c5hlund, Viveka", "Engblom, Sten"], "dc.date.issued": "2019", "dc.language.iso": "swe", "dc.publisher": ["Vaasan yliopisto"]}

# %%
# Analyze the statistics of the extracted metadata and save to file
model_name = 'zephyr-7b'

import sys
sys.path.append('..')

from eval import MetadataEvaluator

evaluator = MetadataEvaluator('test-records.jsonl')
results = evaluator.evaluate_records() #prediction_records[:9])
# Use only the fields that Meteor extracts
fields = [
        "dc.contributor.author",
        "dc.date.issued",
        "dc.identifier.isbn",
        "dc.language.iso",
        "dc.publisher",
        "dc.relation.eissn",
        "dc.title",
    ]
statistics_filename = '../results-ludwig-fine-tune-' + model_name + '.md'
evaluator.save_md(results, statistics_filename, fields)

# %% [raw]
# # statistics etc. about fine-tune/prediction runs
#
# English-only records
#
# TEXT_LENGTH fields  #test_df  batch_size loaded? pred_time  GPU_VRAM
# 1024        title   59        128        no      killed
# 1024        title   10        128        no      21s
# 1024        title   59        128        no      killed
# 1024        title   59        16         yes     killed     12GB
# 1024        title   32        16         yes     55s        12GB
# 1024        title   27 [32:]  16         yes     41s        12GB
# 1024        title   48        16         yes     killed     12GB
# 1024        title   32        16         yes     55s        12GB
# 1024        meteor  32        16         no      268s       13GB    XML output!? (2 epochs)
# 1024        meteor  32        16         no      231s       13.5GB  JSON, 3 epochs
# 2048?       meteor  32        16         no      233s       13GB    XML, 3 epochs
# 2048        meteor  32        16         no      211s       13.5GB  JSON, 3 epochs (JSON prompt)
# 2048        meteor  59        16         no      killed     13.5GB
# 2048        meteor  32+27     16         yes     344s       13GB
#
# All 3 languages (fi, sv, en)
# TEXT_LENGTH fields  #test_df  batch_size loaded? pred_time  GPU_VRAM
# 2048        meteor  32+135    16         no      killed     14GB
# 2048        meteor  167 (b32) 16         yes     ~20min     14GB
# 3072        meteor  167 (b32) 16         no      ~22min     18GB
